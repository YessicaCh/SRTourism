# %%
import pprint
import rdflib
from rdflib import Graph, URIRef, Literal,RDF,RDFS
from rdflib.namespace import FOAF

g = Graph()
bob = URIRef("http://example.org/people/Bob")

g.add((bob, FOAF.age, Literal(42)))
print(f"Bob is {g.value(bob, FOAF.age)}")
# prints: Bob is 42
# Out:
# Bob is 42

# %%
graph = rdflib.Graph()
graph = rdflib.Graph()

# %%
print(g)
# Out:
# [a rdfg:Graph;rdflib:storage [a rdflib:Store;rdfs:label 'Memory']].

# %%
path = '/home/yessica/Documentos/2021/ProyectoTesis/SR/SRTourism/ontology.ttl'
g.parse(path,format = 'ttl')
v = g.serialize(format="xml")

#print(g.serialize())

for subj, pred, obj in g:
    
    print('->subj ', subj)
    print('->pred ', pred)
    print('->obj ', obj)
    print('\n')
# Out:
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#lastUpdate
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Last update date in partner datastore
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#hasFloorSize
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  has floor size
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#ScaleRating
# ->pred  http://www.w3.org/2000/01/rdf-schema#subClassOf
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#Rating
#
#
# ->subj  n03d05955926f4f0687d1a17f53e229d1b115
# ->pred  http://www.w3.org/2002/07/owl#unionOf
# ->obj  n03d05955926f4f0687d1a17f53e229d1b116
#
#
# ->subj  http://www.w3.org/2001/XMLSchema#time
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2000/01/rdf-schema#Datatype
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#GarageOrAirPump
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#Class
#
#
# ->subj  n03d05955926f4f0687d1a17f53e229d1b120
# ->pred  http://www.w3.org/2002/07/owl#onProperty
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#isRatingProvidedBy
#
#
# ->subj  ne4a40a6216cc4fcb97e2a37a48a49927b56
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#rest
# ->obj  http://www.w3.org/1999/02/22-rdf-syntax-ns#nil
#
#
# ->subj  n102b735c64894081a9c81b809fa4ad05b53
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#rest
# ->obj  http://www.w3.org/1999/02/22-rdf-syntax-ns#nil
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#credits
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Credits
#
#
# ->subj  n951192e6c456490694ff6ea6bb0009e1b123
# ->pred  http://www.w3.org/2002/07/owl#allValuesFrom
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#CommonFeatureSpecification
#
#
# ->subj  n03d05955926f4f0687d1a17f53e229d1b23
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#rest
# ->obj  n03d05955926f4f0687d1a17f53e229d1b24
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#providesCuisineOfType
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  provides cuisine of type
#
#
# ->subj  n102b735c64894081a9c81b809fa4ad05b56
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#first
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#RoomFeatureSpecification
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#HealthTheme
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Thème de santé
#
#
# ->subj  nf8b15d95d1924408a5ade23fc16badf0b94
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#Restriction
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#TourismCentre
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#Class
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#isCompliantWith
# ->pred  http://www.w3.org/2000/01/rdf-schema#domain
# ->obj  n03d05955926f4f0687d1a17f53e229d1b10
#
#
# ->subj  nf8b15d95d1924408a5ade23fc16badf0b86
# ->pred  http://www.w3.org/2002/07/owl#allValuesFrom
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#CommonAmenity
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#maxAltitude
# ->pred  http://www.w3.org/2000/01/rdf-schema#domain
# ->obj  nf8b15d95d1924408a5ade23fc16badf0b57
#
#
# ->subj  nf8b15d95d1924408a5ade23fc16badf0b79
# ->pred  http://www.w3.org/2002/07/owl#allValuesFrom
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#CommonFeatureSpecification
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#WalkingTour
# ->pred  http://www.w3.org/2000/01/rdf-schema#subClassOf
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#Tour
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#TaxiCompany
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#Class
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#hasBookingContact
# ->pred  http://www.w3.org/2000/01/rdf-schema#subPropertyOf
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#hasContact
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#SquashCourt
# ->pred  http://www.w3.org/2000/01/rdf-schema#subClassOf
# ->obj  http://schema.org/LocalBusiness
#
#
# ->subj  ncac9cf0d8d874013bffc8762dc44494eb14
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#rest
# ->obj  ncac9cf0d8d874013bffc8762dc44494eb15
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#startDate
# ->pred  http://www.w3.org/2000/01/rdf-schema#domain
# ->obj  n022a854a831943ecb7bbedbb1a622ec0b69
#
#
# ->subj  ncac9cf0d8d874013bffc8762dc44494eb42
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#rest
# ->obj  ncac9cf0d8d874013bffc8762dc44494eb43
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#Market
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Market
#
#
# ->subj  nc7676ee9b534471581e31dcfe69744c1b127
# ->pred  http://www.w3.org/2002/07/owl#unionOf
# ->obj  nc7676ee9b534471581e31dcfe69744c1b128
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#MedicalPlace
# ->pred  http://www.w3.org/2000/01/rdf-schema#subClassOf
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#PlaceOfInterest
#
#
# ->subj  n102b735c64894081a9c81b809fa4ad05b87
# ->pred  http://www.w3.org/2002/07/owl#allValuesFrom
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#CommonFeatureSpecification
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#worstRating
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Pire note
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#hasBookingContact
# ->pred  http://www.w3.org/2000/01/rdf-schema#comment
# ->obj  The agent to contact in case of booking matters.
#
#
# ->subj  n022a854a831943ecb7bbedbb1a622ec0b41
# ->pred  http://www.w3.org/2002/07/owl#unionOf
# ->obj  n022a854a831943ecb7bbedbb1a622ec0b42
#
#
# ->subj  nc7676ee9b534471581e31dcfe69744c1b118
# ->pred  http://www.w3.org/2002/07/owl#onProperty
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#hasFeature
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#Chalet
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Chalet
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#CircusEvent
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#Class
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#Hillsides
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Hillsides
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#Harvest
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Harvest
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#BoutiqueOrLocalShop
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Boutique or local shop
#
#
# ->subj  ncac9cf0d8d874013bffc8762dc44494eb5
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#first
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#PointOfInterest
#
#
# ->subj  n102b735c64894081a9c81b809fa4ad05b125
# ->pred  http://www.w3.org/2002/07/owl#onProperty
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#hasFeature
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#rightsStartDate
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#DatatypeProperty
#
#
# ->subj  ne4a40a6216cc4fcb97e2a37a48a49927b130
# ->pred  http://www.w3.org/2002/07/owl#onProperty
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#isOwnedBy
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#hasEligiblePolicy
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#FunctionalProperty
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#rightsStartDate
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Rights starting date
#
#
# ->subj  ne4a40a6216cc4fcb97e2a37a48a49927b106
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#Restriction
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#FastFoodRestaurant
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#Class
#
#
# ->subj  ncac9cf0d8d874013bffc8762dc44494eb12
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#rest
# ->obj  http://www.w3.org/1999/02/22-rdf-syntax-ns#nil
#
#
# ->subj  ne4a40a6216cc4fcb97e2a37a48a49927b75
# ->pred  http://www.w3.org/2002/07/owl#unionOf
# ->obj  ne4a40a6216cc4fcb97e2a37a48a49927b76
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#Canyon
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#Class
#
#
# ->subj  n951192e6c456490694ff6ea6bb0009e1b116
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#rest
# ->obj  n951192e6c456490694ff6ea6bb0009e1b117
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#Concert
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#Class
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#PricingMode
# ->pred  http://www.w3.org/2000/01/rdf-schema#comment
# ->obj  The pricing mode. e.g. daily, monthly, per person, ...
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#Stream
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Ruisseau
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#DownhillSkiRun
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Downhill ski run
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#IceCreamShop
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Glacier
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#hasReview
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  a pour classement
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#EntertainmentAndEvent
# ->pred  http://www.w3.org/2000/01/rdf-schema#subClassOf
# ->obj  nf8b15d95d1924408a5ade23fc16badf0b93
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#hasLocomotionWay
# ->pred  http://www.w3.org/2000/01/rdf-schema#comment
# ->obj  Le mode de locomotion.
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#hasReview
# ->pred  http://www.w3.org/2000/01/rdf-schema#comment
# ->obj  A Review which rates this POI.
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#DepartmentStore
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#Class
#
#
# ->subj  n03d05955926f4f0687d1a17f53e229d1b22
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#Class
#
#
# ->subj  n022a854a831943ecb7bbedbb1a622ec0b114
# ->pred  http://www.w3.org/2002/07/owl#onProperty
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#hasFeature
#
#
# ->subj  n951192e6c456490694ff6ea6bb0009e1b52
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#first
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#Department
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#hasFloorSize
# ->pred  http://www.w3.org/2000/01/rdf-schema#domain
# ->obj  ncac9cf0d8d874013bffc8762dc44494eb1
#
#
# ->subj  nf8b15d95d1924408a5ade23fc16badf0b67
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#first
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#Place
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#worstRating
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Worst rating
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#HealthcarePlace
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#Class
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#AlpinePasture
# ->pred  http://www.w3.org/2000/01/rdf-schema#subClassOf
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#NaturalHeritage
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#hasFeature
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#ObjectProperty
#
#
# ->subj  ne4a40a6216cc4fcb97e2a37a48a49927b104
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#Restriction
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#Pier
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Pier
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#RoomAmenity
# ->pred  http://www.w3.org/2000/01/rdf-schema#comment
# ->obj  Rooms a place can provide: E.g. amphitheatre, box, exhibition hall
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#FoodEstablishment
# ->pred  http://www.w3.org/2000/01/rdf-schema#subClassOf
# ->obj  ncac9cf0d8d874013bffc8762dc44494eb95
#
#
# ->subj  nf8b15d95d1924408a5ade23fc16badf0b14
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#first
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#Annotation
#
#
# ->subj  n022a854a831943ecb7bbedbb1a622ec0b119
# ->pred  http://www.w3.org/2002/07/owl#onProperty
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#features
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#AccommodationProduct
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#Class
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#startDate
# ->pred  http://www.w3.org/2000/01/rdf-schema#domain
# ->obj  n951192e6c456490694ff6ea6bb0009e1b69
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#Pharmacy
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#Class
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#lifeguarded
# ->pred  http://www.w3.org/2000/01/rdf-schema#comment
# ->obj  True if this beach is lifeguarded.
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#AccommodationFeatureSpecification
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Accommodation feature specification
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#hasGeographicReach
# ->pred  http://www.w3.org/2000/01/rdf-schema#comment
# ->obj  The geographical reach of this POI: international... local.
#
#
# ->subj  nf8b15d95d1924408a5ade23fc16badf0b106
# ->pred  http://www.w3.org/2002/07/owl#onProperty
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#hasReviewValue
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#hasPublished
# ->pred  http://www.w3.org/2000/01/rdf-schema#comment
# ->obj  Le POI que cet Agent a publié.
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#RoomFeatureSpecification
# ->pred  http://www.w3.org/2000/01/rdf-schema#subClassOf
# ->obj  n022a854a831943ecb7bbedbb1a622ec0b119
#
#
# ->subj  n03d05955926f4f0687d1a17f53e229d1b93
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#Restriction
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#allowedPersons
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Capacity (number of persons)
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#hasPricingMode
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  has pricing mode
#
#
# ->subj  nf8b15d95d1924408a5ade23fc16badf0b89
# ->pred  http://www.w3.org/2002/07/owl#allValuesFrom
# ->obj  nf8b15d95d1924408a5ade23fc16badf0b90
#
#
# ->subj  nc7676ee9b534471581e31dcfe69744c1b104
# ->pred  http://www.w3.org/2002/07/owl#allValuesFrom
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#InformativeAmenity
#
#
# ->subj  ncac9cf0d8d874013bffc8762dc44494eb78
# ->pred  http://www.w3.org/2002/07/owl#onProperty
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#features
#
#
# ->subj  ne4a40a6216cc4fcb97e2a37a48a49927b20
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#rest
# ->obj  ne4a40a6216cc4fcb97e2a37a48a49927b21
#
#
# ->subj  nf8b15d95d1924408a5ade23fc16badf0b6
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#rest
# ->obj  http://www.w3.org/1999/02/22-rdf-syntax-ns#nil
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#TaxiCompany
# ->pred  http://www.w3.org/2000/01/rdf-schema#subClassOf
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#ServiceProvider
#
#
# ->subj  n022a854a831943ecb7bbedbb1a622ec0b35
# ->pred  http://www.w3.org/2002/07/owl#unionOf
# ->obj  n022a854a831943ecb7bbedbb1a622ec0b36
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#Period
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Period
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#BoutiqueOrLocalShop
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#Class
#
#
# ->subj  ne4a40a6216cc4fcb97e2a37a48a49927b121
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#Restriction
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#HypermarketAndSupermarket
# ->pred  http://www.w3.org/2000/01/rdf-schema#subClassOf
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#Store
#
#
# ->subj  ne4a40a6216cc4fcb97e2a37a48a49927b81
# ->pred  http://www.w3.org/2002/07/owl#unionOf
# ->obj  ne4a40a6216cc4fcb97e2a37a48a49927b82
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#DogSleddingTrail
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Dog sledding trail
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#GeneralPricingOffer
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  General pricing Offer
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#Parade
# ->pred  http://www.w3.org/2000/01/rdf-schema#subClassOf
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#SocialEvent
#
#
# ->subj  nc7676ee9b534471581e31dcfe69744c1b81
# ->pred  http://www.w3.org/2002/07/owl#unionOf
# ->obj  nc7676ee9b534471581e31dcfe69744c1b82
#
#
# ->subj  nc7676ee9b534471581e31dcfe69744c1b101
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#first
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#CommonFeatureSpecification
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#BilliardRoom
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#Class
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#pending
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#DatatypeProperty
#
#
# ->subj  n951192e6c456490694ff6ea6bb0009e1b82
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#rest
# ->obj  n951192e6c456490694ff6ea6bb0009e1b83
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#tourDistance
# ->pred  http://www.w3.org/2000/01/rdf-schema#domain
# ->obj  ne4a40a6216cc4fcb97e2a37a48a49927b75
#
#
# ->subj  n951192e6c456490694ff6ea6bb0009e1b102
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#first
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#HotelFeatureSpecification
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#Reading
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Lecture
#
#
# ->subj  nf8b15d95d1924408a5ade23fc16badf0b14
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#rest
# ->obj  nf8b15d95d1924408a5ade23fc16badf0b15
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#Monastery
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Monastère, prieuré
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#hasLocomotionWay
# ->pred  http://www.w3.org/2000/01/rdf-schema#comment
# ->obj  The way of locomotion.
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#EquestrianCenter
# ->pred  http://www.w3.org/2000/01/rdf-schema#subClassOf
# ->obj  http://schema.org/LocalBusiness
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#isDedicatedTo
# ->pred  http://www.w3.org/2000/01/rdf-schema#domain
# ->obj  nf8b15d95d1924408a5ade23fc16badf0b13
#
#
# ->subj  http://schema.org/Event
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#Class
#
#
# ->subj  n951192e6c456490694ff6ea6bb0009e1b77
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#rest
# ->obj  http://www.w3.org/1999/02/22-rdf-syntax-ns#nil
#
#
# ->subj  nf8b15d95d1924408a5ade23fc16badf0b4
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#Class
#
#
# ->subj  n951192e6c456490694ff6ea6bb0009e1b9
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#first
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#TourPath
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#Cellar
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Cave ou caveau
#
#
# ->subj  n03d05955926f4f0687d1a17f53e229d1b70
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#first
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#LimitedPeriod
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#AccommodationPricingOffer
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#Class
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#TechnicalHeritage
# ->pred  http://www.w3.org/2000/01/rdf-schema#subClassOf
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#CulturalSite
#
#
# ->subj  n951192e6c456490694ff6ea6bb0009e1b19
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#Class
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#RoomAmenity
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#Class
#
#
# ->subj  n022a854a831943ecb7bbedbb1a622ec0b7
# ->pred  http://www.w3.org/2002/07/owl#unionOf
# ->obj  n022a854a831943ecb7bbedbb1a622ec0b8
#
#
# ->subj  nf8b15d95d1924408a5ade23fc16badf0b123
# ->pred  http://www.w3.org/2002/07/owl#onProperty
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#hasFeature
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core
# ->pred  http://www.w3.org/2002/07/owl#imports
# ->obj  http://topbraid.org/schema/
#
#
# ->subj  nf8b15d95d1924408a5ade23fc16badf0b41
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#Class
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#occupancy
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Occupancy
#
#
# ->subj  nf8b15d95d1924408a5ade23fc16badf0b40
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#rest
# ->obj  http://www.w3.org/1999/02/22-rdf-syntax-ns#nil
#
#
# ->subj  ncac9cf0d8d874013bffc8762dc44494eb67
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#first
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#Place
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#occupancy
# ->pred  http://www.w3.org/2000/01/rdf-schema#comment
# ->obj  Le nombre maximum de personnes possibles sur la surface concernée.
#
#
# ->subj  nf8b15d95d1924408a5ade23fc16badf0b69
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#Class
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#CommonAmenity
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Basic facilities and service
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#RoomLayout
# ->pred  http://www.w3.org/2000/01/rdf-schema#comment
# ->obj  La disposition de la salle. Ex: en banquet, en U, en cocktail, ...
#
#
# ->subj  n03d05955926f4f0687d1a17f53e229d1b76
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#first
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#Tour
#
#
# ->subj  n03d05955926f4f0687d1a17f53e229d1b21
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#first
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#TourPath
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#additionalInformation
# ->pred  http://www.w3.org/2000/01/rdf-schema#domain
# ->obj  n951192e6c456490694ff6ea6bb0009e1b29
#
#
# ->subj  n102b735c64894081a9c81b809fa4ad05b108
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#Restriction
#
#
# ->subj  n951192e6c456490694ff6ea6bb0009e1b2
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#rest
# ->obj  n951192e6c456490694ff6ea6bb0009e1b3
#
#
# ->subj  n022a854a831943ecb7bbedbb1a622ec0b66
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#Class
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#Cloister
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Cloître
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#hasInformativeContact
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  a pour contact informatif
#
#
# ->subj  n102b735c64894081a9c81b809fa4ad05b47
# ->pred  http://www.w3.org/2002/07/owl#unionOf
# ->obj  n102b735c64894081a9c81b809fa4ad05b48
#
#
# ->subj  ne4a40a6216cc4fcb97e2a37a48a49927b43
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#first
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#RecurrentPeriod
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#Mosque
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Mosque
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#Exhibition
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Exposition
#
#
# ->subj  n022a854a831943ecb7bbedbb1a622ec0b114
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#Restriction
#
#
# ->subj  nf8b15d95d1924408a5ade23fc16badf0b114
# ->pred  http://www.w3.org/2002/07/owl#allValuesFrom
# ->obj  nf8b15d95d1924408a5ade23fc16badf0b115
#
#
# ->subj  n102b735c64894081a9c81b809fa4ad05b79
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#Restriction
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#guided
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#FunctionalProperty
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#hasClientTarget
# ->pred  http://www.w3.org/2000/01/rdf-schema#range
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#PeopleAudience
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#registeredNumber
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#DatatypeProperty
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#DogSleddingTrail
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Piste de chien de traineau
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#SwimmingPool
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Swimming pool
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#duration
# ->pred  http://www.w3.org/2000/01/rdf-schema#domain
# ->obj  n951192e6c456490694ff6ea6bb0009e1b38
#
#
# ->subj  n951192e6c456490694ff6ea6bb0009e1b45
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#rest
# ->obj  n951192e6c456490694ff6ea6bb0009e1b46
#
#
# ->subj  ncac9cf0d8d874013bffc8762dc44494eb18
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#rest
# ->obj  http://www.w3.org/1999/02/22-rdf-syntax-ns#nil
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#CulturalActivityProvider
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#Class
#
#
# ->subj  http://schema.org/Park
# ->pred  http://www.w3.org/2002/07/owl#equivalentClass
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#ParkAndGarden
#
#
# ->subj  n951192e6c456490694ff6ea6bb0009e1b129
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#rest
# ->obj  http://www.w3.org/1999/02/22-rdf-syntax-ns#nil
#
#
# ->subj  n951192e6c456490694ff6ea6bb0009e1b131
# ->pred  http://www.w3.org/2002/07/owl#allValuesFrom
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#CommonFeatureSpecification
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#allowedPersons
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#FunctionalProperty
#
#
# ->subj  ne4a40a6216cc4fcb97e2a37a48a49927b129
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#first
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#TastingFeatureSpecification
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#Room
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Chambre
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#AlpinePasture
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Alpine pasture
#
#
# ->subj  n102b735c64894081a9c81b809fa4ad05b84
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#Restriction
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#Cinema
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#Class
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#District
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#Class
#
#
# ->subj  n022a854a831943ecb7bbedbb1a622ec0b84
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#Restriction
#
#
# ->subj  nf8b15d95d1924408a5ade23fc16badf0b72
# ->pred  http://www.w3.org/2002/07/owl#unionOf
# ->obj  nf8b15d95d1924408a5ade23fc16badf0b73
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#Fountain
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Fontaine
#
#
# ->subj  n03d05955926f4f0687d1a17f53e229d1b121
# ->pred  http://www.w3.org/2002/07/owl#allValuesFrom
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#ScaleRating
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#Store
# ->pred  http://www.w3.org/2000/01/rdf-schema#subClassOf
# ->obj  nf8b15d95d1924408a5ade23fc16badf0b125
#
#
# ->subj  nf8b15d95d1924408a5ade23fc16badf0b92
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#rest
# ->obj  http://www.w3.org/1999/02/22-rdf-syntax-ns#nil
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#CulturalHeritageAmenity
# ->pred  http://www.w3.org/2000/01/rdf-schema#comment
# ->obj  Amenity provided by cultural heritage.
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#PicnicArea
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Picnic area
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#FortifiedSet
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Fortified set
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#PriceSpecification
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#Class
#
#
# ->subj  ne4a40a6216cc4fcb97e2a37a48a49927b92
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#rest
# ->obj  http://www.w3.org/1999/02/22-rdf-syntax-ns#nil
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#Bubble
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Bubble
#
#
# ->subj  ncac9cf0d8d874013bffc8762dc44494eb114
# ->pred  http://www.w3.org/2002/07/owl#onProperty
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#hasFeature
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#meets
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#ObjectProperty
#
#
# ->subj  ne4a40a6216cc4fcb97e2a37a48a49927b108
# ->pred  http://www.w3.org/2002/07/owl#allValuesFrom
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#CommonFeatureSpecification
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#TennisComplex
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#Class
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#IslandPeninsula
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Island peninsula
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#providesFoodProduct
# ->pred  http://www.w3.org/2000/01/rdf-schema#domain
# ->obj  n03d05955926f4f0687d1a17f53e229d1b22
#
#
# ->subj  nf8b15d95d1924408a5ade23fc16badf0b98
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#rest
# ->obj  http://www.w3.org/1999/02/22-rdf-syntax-ns#nil
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#airConditioning
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#DatatypeProperty
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#Product
# ->pred  http://www.w3.org/2000/01/rdf-schema#comment
# ->obj  Un produit est un objet touristique qui peut être consommé.
#
#
# ->subj  http://schema.org/Airport
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#Class
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#FeatureSpecification
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Feature specification
#
#
# ->subj  ncac9cf0d8d874013bffc8762dc44494eb97
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#rest
# ->obj  ncac9cf0d8d874013bffc8762dc44494eb98
#
#
# ->subj  nc7676ee9b534471581e31dcfe69744c1b70
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#first
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#LimitedPeriod
#
#
# ->subj  nf8b15d95d1924408a5ade23fc16badf0b91
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#rest
# ->obj  nf8b15d95d1924408a5ade23fc16badf0b92
#
#
# ->subj  nc7676ee9b534471581e31dcfe69744c1b123
# ->pred  http://www.w3.org/2002/07/owl#allValuesFrom
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#CommonFeatureSpecification
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#ScaleReview
# ->pred  http://www.w3.org/2000/01/rdf-schema#subClassOf
# ->obj  nf8b15d95d1924408a5ade23fc16badf0b121
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#hasEligiblePolicy
# ->pred  http://www.w3.org/2000/01/rdf-schema#comment
# ->obj  The pricing policy the pricing applies on. Ex: Base rate.
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#WineCellar
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Cave de dégustation
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#Concert
# ->pred  http://www.w3.org/2000/01/rdf-schema#subClassOf
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#CulturalEvent
#
#
# ->subj  n951192e6c456490694ff6ea6bb0009e1b39
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#rest
# ->obj  n951192e6c456490694ff6ea6bb0009e1b40
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#TastingProvider
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Fournisseur de dégustation
#
#
# ->subj  n951192e6c456490694ff6ea6bb0009e1b120
# ->pred  http://www.w3.org/2002/07/owl#allValuesFrom
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#ScaleReviewSystem
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#FortifiedCastle
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Château fort
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#credits
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Crédits
#
#
# ->subj  nf8b15d95d1924408a5ade23fc16badf0b110
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#Class
#
#
# ->subj  ne4a40a6216cc4fcb97e2a37a48a49927b105
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#Restriction
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#PeopleAudience
# ->pred  http://www.w3.org/2000/01/rdf-schema#comment
# ->obj  An audience composed of group of persons.
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#saleOnSite
# ->pred  http://www.w3.org/2000/01/rdf-schema#range
# ->obj  http://www.w3.org/2001/XMLSchema#boolean
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#seatCount
# ->pred  http://www.w3.org/2000/01/rdf-schema#comment
# ->obj  The number of seats available in the concerned area
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#noSmoking
# ->pred  http://www.w3.org/2000/01/rdf-schema#domain
# ->obj  ncac9cf0d8d874013bffc8762dc44494eb63
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#StopOverOrGroupLodge
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Refuge or overnight shelter
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#Parking
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Parking
#
#
# ->subj  n951192e6c456490694ff6ea6bb0009e1b60
# ->pred  http://www.w3.org/2002/07/owl#unionOf
# ->obj  n951192e6c456490694ff6ea6bb0009e1b61
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#ScaleReview
# ->pred  http://www.w3.org/2000/01/rdf-schema#comment
# ->obj  Un classement qui associe un Produit avec un score en accord avec un ScaleReviewSystem donné (a ScaleRating). ex : 3 étoiles.
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#airConditioning
# ->pred  http://www.w3.org/2000/01/rdf-schema#domain
# ->obj  ncac9cf0d8d874013bffc8762dc44494eb32
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#hasPart
# ->pred  http://www.w3.org/2000/01/rdf-schema#comment
# ->obj  Un sous-produit de ce produit (par exemple si le produit est un composant de celui-ci). Ex: un court de golf dans un camping.
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#CommonAmenity
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#Class
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#Tour
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Route
#
#
# ->subj  n022a854a831943ecb7bbedbb1a622ec0b103
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#first
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#RoomFeatureSpecification
#
#
# ->subj  nf8b15d95d1924408a5ade23fc16badf0b124
# ->pred  http://www.w3.org/2002/07/owl#onProperty
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#hasFeature
#
#
# ->subj  ne4a40a6216cc4fcb97e2a37a48a49927b122
# ->pred  http://www.w3.org/2002/07/owl#onProperty
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#allowsRating
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#CateringAmenity
# ->pred  http://www.w3.org/2000/01/rdf-schema#subClassOf
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#Amenity
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#Rambling
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#Class
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#maxAltitude
# ->pred  http://www.w3.org/2000/01/rdf-schema#comment
# ->obj  The altitude of the highest point in the path. Unit is meter
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#HealthcarePlace
# ->pred  http://www.w3.org/2000/01/rdf-schema#comment
# ->obj  A place where someone can receive healthcare (a hospital, a clinic, ...)
#
#
# ->subj  nf8b15d95d1924408a5ade23fc16badf0b81
# ->pred  http://www.w3.org/2002/07/owl#unionOf
# ->obj  nf8b15d95d1924408a5ade23fc16badf0b82
#
#
# ->subj  http://schema.org/BusStop
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#Class
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#availableLanguage
# ->pred  http://www.w3.org/2000/01/rdf-schema#domain
# ->obj  n022a854a831943ecb7bbedbb1a622ec0b35
#
#
# ->subj  nf8b15d95d1924408a5ade23fc16badf0b15
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#first
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#Description
#
#
# ->subj  n022a854a831943ecb7bbedbb1a622ec0b49
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#first
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#TourPath
#
#
# ->subj  n03d05955926f4f0687d1a17f53e229d1b103
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#first
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#RoomFeatureSpecification
#
#
# ->subj  nf8b15d95d1924408a5ade23fc16badf0b123
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#Restriction
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#ATM
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Distributeur automatique de billets, DAB
#
#
# ->subj  ne4a40a6216cc4fcb97e2a37a48a49927b55
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#first
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#Place
#
#
# ->subj  ne4a40a6216cc4fcb97e2a37a48a49927b93
# ->pred  http://www.w3.org/2002/07/owl#allValuesFrom
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#CommonFeatureSpecification
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#TourPath
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Etape de l'itinéraire
#
#
# ->subj  nc7676ee9b534471581e31dcfe69744c1b123
# ->pred  http://www.w3.org/2002/07/owl#onProperty
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#hasFeature
#
#
# ->subj  n022a854a831943ecb7bbedbb1a622ec0b30
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#rest
# ->obj  n022a854a831943ecb7bbedbb1a622ec0b31
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#hasRepresentation
# ->pred  http://www.w3.org/2000/01/rdf-schema#domain
# ->obj  n102b735c64894081a9c81b809fa4ad05b7
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#Rating
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#Class
#
#
# ->subj  n951192e6c456490694ff6ea6bb0009e1b68
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#rest
# ->obj  http://www.w3.org/1999/02/22-rdf-syntax-ns#nil
#
#
# ->subj  ne4a40a6216cc4fcb97e2a37a48a49927b2
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#rest
# ->obj  ne4a40a6216cc4fcb97e2a37a48a49927b3
#
#
# ->subj  http://schema.org/NightClub
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#Class
#
#
# ->subj  n102b735c64894081a9c81b809fa4ad05b30
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#rest
# ->obj  n102b735c64894081a9c81b809fa4ad05b31
#
#
# ->subj  n022a854a831943ecb7bbedbb1a622ec0b68
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#first
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#RoomFeatureSpecification
#
#
# ->subj  ncac9cf0d8d874013bffc8762dc44494eb126
# ->pred  http://www.w3.org/2002/07/owl#onProperty
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#hasFeature
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#Temple
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#Class
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#Gymnasium
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Gymnasium or sports field
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#PlaceOfInterest
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Lieu
#
#
# ->subj  n102b735c64894081a9c81b809fa4ad05b25
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#first
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#TastingProvider
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#CampingCar
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Camping car
#
#
# ->subj  ncac9cf0d8d874013bffc8762dc44494eb29
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#Class
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#cedex
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#FunctionalProperty
#
#
# ->subj  nc7676ee9b534471581e31dcfe69744c1b80
# ->pred  http://www.w3.org/2002/07/owl#onProperty
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#hasFeature
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#bestRating
# ->pred  http://www.w3.org/2000/01/rdf-schema#comment
# ->obj  Le score le plus haut que le système de classement propose.
#
#
# ->subj  n102b735c64894081a9c81b809fa4ad05b56
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#rest
# ->obj  http://www.w3.org/1999/02/22-rdf-syntax-ns#nil
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#appliesOnDay
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  s'applique sur le jour de la semaine
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#NaturalCuriosity
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Natural curiosity
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#Bridge
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Bridge
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#ArtGalleryOrExhibitionGallery
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Art gallery, exhibition gallery
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#COVID19InOperationConfirmed
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#FunctionalProperty
#
#
# ->subj  nf8b15d95d1924408a5ade23fc16badf0b8
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#first
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#PointOfInterest
#
#
# ->subj  n951192e6c456490694ff6ea6bb0009e1b17
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#rest
# ->obj  n951192e6c456490694ff6ea6bb0009e1b18
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#ClimbingWall
# ->pred  http://www.w3.org/2000/01/rdf-schema#subClassOf
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#SportsAndLeisurePlace
#
#
# ->subj  n03d05955926f4f0687d1a17f53e229d1b11
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#first
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#Rating
#
#
# ->subj  nc7676ee9b534471581e31dcfe69744c1b65
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#rest
# ->obj  http://www.w3.org/1999/02/22-rdf-syntax-ns#nil
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#Glacier
# ->pred  http://www.w3.org/2000/01/rdf-schema#subClassOf
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#NaturalHeritage
#
#
# ->subj  nf8b15d95d1924408a5ade23fc16badf0b58
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#rest
# ->obj  nf8b15d95d1924408a5ade23fc16badf0b59
#
#
# ->subj  n03d05955926f4f0687d1a17f53e229d1b126
# ->pred  http://www.w3.org/2002/07/owl#allValuesFrom
# ->obj  n03d05955926f4f0687d1a17f53e229d1b127
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#NaturalHeritageAmenity
# ->pred  http://www.w3.org/2000/01/rdf-schema#comment
# ->obj  Équipement ou service proposé dans un patrimoine naturel.
#
#
# ->subj  ne4a40a6216cc4fcb97e2a37a48a49927b105
# ->pred  http://www.w3.org/2002/07/owl#allValuesFrom
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#LabelReviewSystem
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#Hillsides
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#Class
#
#
# ->subj  n951192e6c456490694ff6ea6bb0009e1b86
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#Restriction
#
#
# ->subj  ne4a40a6216cc4fcb97e2a37a48a49927b31
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#first
# ->obj  http://schema.org/PriceSpecification
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#FairOrShow
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#Class
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#endTime
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#DatatypeProperty
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#rightsStartDate
# ->pred  http://www.w3.org/2000/01/rdf-schema#range
# ->obj  http://www.w3.org/2001/XMLSchema#date
#
#
# ->subj  n102b735c64894081a9c81b809fa4ad05b85
# ->pred  http://www.w3.org/2002/07/owl#allValuesFrom
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#CateringAmenity
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#WineCellar
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#Class
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#isEquippedWith
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#ObjectProperty
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#maxAltitude
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Altitude maximale
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#FitnessCenter
# ->pred  http://www.w3.org/2000/01/rdf-schema#subClassOf
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#SportsAndLeisurePlace
#
#
# ->subj  n102b735c64894081a9c81b809fa4ad05b87
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#Restriction
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#isPartOfRegion
# ->pred  https://www.datatourisme.gouv.fr/ontology/core#hasPriority
# ->obj  9.0
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#hasLocomotionWay
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  has way of locomotion
#
#
# ->subj  nf8b15d95d1924408a5ade23fc16badf0b83
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#first
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#CommonFeatureSpecification
#
#
# ->subj  n951192e6c456490694ff6ea6bb0009e1b136
# ->pred  http://www.w3.org/2002/07/owl#allValuesFrom
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#CommonFeatureSpecification
#
#
# ->subj  nf8b15d95d1924408a5ade23fc16badf0b24
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#rest
# ->obj  nf8b15d95d1924408a5ade23fc16badf0b25
#
#
# ->subj  n03d05955926f4f0687d1a17f53e229d1b24
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#first
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#Tasting
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#Camping
# ->pred  http://www.w3.org/2000/01/rdf-schema#subClassOf
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#CampingAndCaravanning
#
#
# ->subj  n951192e6c456490694ff6ea6bb0009e1b62
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#rest
# ->obj  http://www.w3.org/1999/02/22-rdf-syntax-ns#nil
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#Fort
# ...
#
#
# ->subj  n022a854a831943ecb7bbedbb1a622ec0b14
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#rest
# ->obj  n022a854a831943ecb7bbedbb1a622ec0b15
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#FitnessCenter
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Fitness centre
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#petsAllowed
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Pets allowed
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#hasBeenCreatedBy
# ->pred  http://www.w3.org/2000/01/rdf-schema#comment
# ->obj  L'agent qui a créé ce POI dans le système d'information.
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#ConventionCentre
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Centre de congrès
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#TennisComplex
# ->pred  http://www.w3.org/2000/01/rdf-schema#subClassOf
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#SportsAndLeisurePlace
#
#
# ->subj  nc7676ee9b534471581e31dcfe69744c1b67
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#rest
# ->obj  nc7676ee9b534471581e31dcfe69744c1b68
#
#
# ->subj  nc7676ee9b534471581e31dcfe69744c1b74
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#first
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#RecurrentPeriod
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#Library
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Library
#
#
# ->subj  nc7676ee9b534471581e31dcfe69744c1b125
# ->pred  http://www.w3.org/2002/07/owl#allValuesFrom
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#CommonFeatureSpecification
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#Volcano
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#Class
#
#
# ->subj  n102b735c64894081a9c81b809fa4ad05b44
# ->pred  http://www.w3.org/2002/07/owl#unionOf
# ->obj  n102b735c64894081a9c81b809fa4ad05b45
#
#
# ->subj  n03d05955926f4f0687d1a17f53e229d1b45
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#rest
# ->obj  n03d05955926f4f0687d1a17f53e229d1b46
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#NonHousingRealEstateRental
# ->pred  http://www.w3.org/2000/01/rdf-schema#subClassOf
# ->obj  ncac9cf0d8d874013bffc8762dc44494eb114
#
#
# ->subj  n022a854a831943ecb7bbedbb1a622ec0b42
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#first
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#LimitedPeriod
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#ScaleReview
# ->pred  http://www.w3.org/2000/01/rdf-schema#subClassOf
# ->obj  n951192e6c456490694ff6ea6bb0009e1b121
#
#
# ->subj  n102b735c64894081a9c81b809fa4ad05b116
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#rest
# ->obj  n102b735c64894081a9c81b809fa4ad05b117
#
#
# ->subj  n03d05955926f4f0687d1a17f53e229d1b88
# ->pred  http://www.w3.org/2002/07/owl#onProperty
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#features
#
#
# ->subj  n951192e6c456490694ff6ea6bb0009e1b27
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#first
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#OpeningHoursSpecification
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#hasAddressCity
# ->pred  http://www.w3.org/2000/01/rdf-schema#comment
# ->obj  The locality of this address
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#Game
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Jeu, concours
#
#
# ->subj  http://schema.org/floorSize
# ->pred  http://www.w3.org/2000/01/rdf-schema#subPropertyOf
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#hasFloorSize
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#Col
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#Class
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#PriceSpecification
# ->pred  http://www.w3.org/2000/01/rdf-schema#comment
# ->obj  Un Tarif aggrège les informations relatives au paiement (l'audience, le mode de tarification, la politique de tarification, la période sur laquelle s'applique le tarif, et le prix chiffré).
#
#
# ->subj  n022a854a831943ecb7bbedbb1a622ec0b45
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#rest
# ->obj  n022a854a831943ecb7bbedbb1a622ec0b46
#
#
# ->subj  ne4a40a6216cc4fcb97e2a37a48a49927b114
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#Restriction
#
#
# ->subj  n022a854a831943ecb7bbedbb1a622ec0b127
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#Class
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#MultiPurposeRoomOrCommunityRoom
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Salle polyvalente, salle des fêtes
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#AntiqueAndSecondhandGoodDealer
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#Class
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#Harvest
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Vendange, récolte
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#worstRating
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#DatatypeProperty
#
#
# ->subj  n951192e6c456490694ff6ea6bb0009e1b133
# ->pred  http://www.w3.org/2002/07/owl#unionOf
# ->obj  n951192e6c456490694ff6ea6bb0009e1b134
#
#
# ->subj  nf8b15d95d1924408a5ade23fc16badf0b75
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#Class
#
#
# ->subj  n03d05955926f4f0687d1a17f53e229d1b120
# ->pred  http://www.w3.org/2002/07/owl#allValuesFrom
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#ScaleReviewSystem
#
#
# ->subj  nc7676ee9b534471581e31dcfe69744c1b17
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#rest
# ->obj  nc7676ee9b534471581e31dcfe69744c1b18
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core
# ->pred  http://www.w3.org/2002/07/owl#imports
# ->obj  http://www.ebu.ch/metadata/ontologies/ebucore/ebucore
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#Convent
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#Class
#
#
# ->subj  ncac9cf0d8d874013bffc8762dc44494eb95
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#Restriction
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#Cliff
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Cliff
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#Bog
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Bog
#
#
# ->subj  nf8b15d95d1924408a5ade23fc16badf0b100
# ->pred  http://www.w3.org/2002/07/owl#unionOf
# ->obj  nf8b15d95d1924408a5ade23fc16badf0b101
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#CulturalSite
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Cultural site
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#ServiceProvider
# ->pred  http://www.w3.org/2000/01/rdf-schema#subClassOf
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#PlaceOfInterest
#
#
# ->subj  n03d05955926f4f0687d1a17f53e229d1b112
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#first
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#NaturalHeritageFeatureSpecification
#
#
# ->subj  nf8b15d95d1924408a5ade23fc16badf0b130
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#Restriction
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#RoomLayout
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Room layout
#
#
# ->subj  n03d05955926f4f0687d1a17f53e229d1b36
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#first
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#InformativeAmenity
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#hasHikeAudience
# ->pred  http://www.w3.org/2000/01/rdf-schema#range
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#PeopleAudience
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#Rental
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Location
#
#
# ->subj  ncac9cf0d8d874013bffc8762dc44494eb118
# ->pred  http://www.w3.org/2002/07/owl#allValuesFrom
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#CommonFeatureSpecification
#
#
# ->subj  nf8b15d95d1924408a5ade23fc16badf0b20
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#first
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#Tour
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core
# ->pred  http://purl.org/dc/elements/1.1/title
# ->obj  DATAtourisme
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#CafeOrTeahouse
# ->pred  http://www.w3.org/2000/01/rdf-schema#subClassOf
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#FoodEstablishment
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#hasInformativeContact
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  has informative contact
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#StreetFood
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Street food
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#endTime
# ->pred  http://www.w3.org/2000/01/rdf-schema#domain
# ->obj  n951192e6c456490694ff6ea6bb0009e1b44
#
#
# ->subj  n022a854a831943ecb7bbedbb1a622ec0b38
# ->pred  http://www.w3.org/2002/07/owl#unionOf
# ->obj  n022a854a831943ecb7bbedbb1a622ec0b39
#
#
# ->subj  n022a854a831943ecb7bbedbb1a622ec0b110
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#Class
#
#
# ->subj  n102b735c64894081a9c81b809fa4ad05b4
# ->pred  http://www.w3.org/2002/07/owl#unionOf
# ->obj  n102b735c64894081a9c81b809fa4ad05b5
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#tourDistance
# ->pred  http://www.w3.org/2000/01/rdf-schema#domain
# ->obj  n951192e6c456490694ff6ea6bb0009e1b75
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#providesCuisineOfType
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  propose une cuisine de type
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#LabelReviewSystem
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Système de classement par label
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#isCompliantWith
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  is compliant with
#
#
# ->subj  nf8b15d95d1924408a5ade23fc16badf0b122
# ->pred  http://www.w3.org/2002/07/owl#onProperty
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#allowsRating
#
#
# ->subj  n03d05955926f4f0687d1a17f53e229d1b115
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#Class
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#CastleAndPrestigeMansion
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#Class
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#EquipmentRepairShop
# ->pred  http://www.w3.org/2000/01/rdf-schema#subClassOf
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#ServiceProvider
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#TableHotes
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Table d'hôtes
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#endTime
# ->pred  http://www.w3.org/2000/01/rdf-schema#domain
# ->obj  ncac9cf0d8d874013bffc8762dc44494eb44
#
#
# ->subj  n951192e6c456490694ff6ea6bb0009e1b37
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#rest
# ->obj  http://www.w3.org/1999/02/22-rdf-syntax-ns#nil
#
#
# ->subj  n102b735c64894081a9c81b809fa4ad05b18
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#rest
# ->obj  http://www.w3.org/1999/02/22-rdf-syntax-ns#nil
#
#
# ->subj  nf8b15d95d1924408a5ade23fc16badf0b33
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#first
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#Place
#
#
# ->subj  http://schema.org/SocialEvent
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#Class
#
#
# ->subj  n022a854a831943ecb7bbedbb1a622ec0b50
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#Class
#
#
# ->subj  ncac9cf0d8d874013bffc8762dc44494eb113
# ->pred  http://www.w3.org/2002/07/owl#onProperty
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#features
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#appliesOnPeriod
# ->pred  http://www.w3.org/2000/01/rdf-schema#domain
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#PriceSpecification
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#Organisation
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Organisation
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#StubbleFields
# ->pred  http://www.w3.org/2000/01/rdf-schema#subClassOf
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#NaturalHeritage
#
#
# ->subj  n022a854a831943ecb7bbedbb1a622ec0b62
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#first
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#TourPath
#
#
# ->subj  http://www.ebu.ch/metadata/ontologies/ebucore/ebucore#EditorialObject
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#Class
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#SportsClub
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#Class
#
#
# ->subj  nf8b15d95d1924408a5ade23fc16badf0b77
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#rest
# ->obj  http://www.w3.org/1999/02/22-rdf-syntax-ns#nil
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#RentalPricingOffer
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#Class
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#endDate
# ->pred  http://www.w3.org/2000/01/rdf-schema#comment
# ->obj  Date à laquelle la période se termine, sans réccurrence interne  (aaaa-mm-jj).
#
#
# ->subj  ne4a40a6216cc4fcb97e2a37a48a49927b11
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#rest
# ->obj  ne4a40a6216cc4fcb97e2a37a48a49927b12
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#Tasting
# ->pred  http://www.w3.org/2000/01/rdf-schema#subClassOf
# ->obj  n03d05955926f4f0687d1a17f53e229d1b126
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#lifeguarded
# ->pred  https://www.datatourisme.gouv.fr/ontology/core#hasPriority
# ->obj  7.0
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#MountainRestaurant
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Restaurant d'altitude / Restaurant d'alpage
#
#
# ->subj  n03d05955926f4f0687d1a17f53e229d1b95
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#Restriction
#
#
# ->subj  n03d05955926f4f0687d1a17f53e229d1b86
# ->pred  http://www.w3.org/2002/07/owl#onProperty
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#features
#
#
# ->subj  n03d05955926f4f0687d1a17f53e229d1b124
# ->pred  http://www.w3.org/2002/07/owl#onProperty
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#hasFeature
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#WalkingTour
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Itinéraire pédestre
#
#
# ->subj  n951192e6c456490694ff6ea6bb0009e1b68
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#first
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#RoomFeatureSpecification
#
#
# ->subj  n022a854a831943ecb7bbedbb1a622ec0b97
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#first
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#CateringFeatureSpecification
#
#
# ->subj  n951192e6c456490694ff6ea6bb0009e1b24
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#first
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#Tasting
#
#
# ->subj  n951192e6c456490694ff6ea6bb0009e1b92
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#first
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#CulturalHeritageAmenity
#
#
# ->subj  nf8b15d95d1924408a5ade23fc16badf0b113
# ->pred  http://www.w3.org/2002/07/owl#allValuesFrom
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#NaturalHeritageAmenity
#
#
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#FortifiedSet
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#Class

# %%
print(g.serialize())
# Out:
# @prefix : <https://www.datatourisme.gouv.fr/ontology/core#> .
# @prefix ns1: <http://purl.org/dc/terms/> .
# @prefix ns2: <http://purl.org/dc/elements/1.1/> .
# @prefix ns3: <http://xmlns.com/foaf/0.1/> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# <http://example.org/people/Bob> ns3:age 42 .
#
# ns2:language a owl:AnnotationProperty .
#
# ns2:rights a owl:AnnotationProperty .
#
# <http://schema.org/Accommodation> a owl:Class ;
#     owl:equivalentClass :AccommodationProduct .
#
# <http://schema.org/Apartment> a owl:Class ;
#     owl:equivalentClass :Apartment .
#
# <http://schema.org/Audience> a owl:Class ;
#     owl:equivalentClass :Audience .
#
# <http://schema.org/BusStation> a owl:Class ;
#     owl:equivalentClass :BusStation .
#
# <http://schema.org/BusStop> a owl:Class ;
#     owl:equivalentClass :BusStop .
#
# <http://schema.org/BusinessEvent> a owl:Class ;
#     owl:equivalentClass :BusinessEvent .
#
# <http://schema.org/DanceEvent> a owl:Class ;
#     owl:equivalentClass :DanceEvent .
#
# <http://schema.org/ExhibitionEvent> a owl:Class ;
#     owl:equivalentClass :Exhibition .
#
# <http://schema.org/FastFoodRestaurant> a owl:Class ;
#     owl:equivalentClass :FastFoodRestaurant .
#
# <http://schema.org/Festival> a owl:Class ;
#     owl:equivalentClass :Festival .
#
# <http://schema.org/GolfCourse> a owl:Class ;
#     owl:equivalentClass :GolfCourse .
#
# <http://schema.org/Hotel> a owl:Class ;
#     owl:equivalentClass :Hotel .
#
# <http://schema.org/House> a owl:Class ;
#     owl:equivalentClass :House .
#
# <http://schema.org/IceCreamShop> a owl:Class ;
#     owl:equivalentClass :IceCreamShop .
#
# <http://schema.org/Landform> a owl:Class ;
#     owl:equivalentClass :NaturalHeritage .
#
# <http://schema.org/Library> a owl:Class ;
#     owl:equivalentClass :Library .
#
# <http://schema.org/Museum> a owl:Class ;
#     owl:equivalentClass :Museum .
#
# <http://schema.org/Park> a owl:Class ;
#     owl:equivalentClass :ParkAndGarden .
#
# <http://schema.org/Pharmacy> a owl:Class ;
#     owl:equivalentClass :Pharmacy .
#
# <http://schema.org/Place> a owl:Class ;
#     owl:equivalentClass :Place .
#
# <http://schema.org/Restaurant> a owl:Class ;
#     owl:equivalentClass :Restaurant .
#
# <http://schema.org/ScreeningEvent> a owl:Class ;
#     owl:equivalentClass :ScreeningEvent .
#
# <http://schema.org/SocialEvent> a owl:Class ;
#     owl:equivalentClass :SocialEvent .
#
# <http://schema.org/Suite> a owl:Class ;
#     owl:equivalentClass :HotelSuite .
#
# <http://schema.org/TheaterEvent> a owl:Class ;
#     owl:equivalentClass :TheaterEvent .
#
# <http://schema.org/TouristInformationCenter> a owl:Class ;
#     owl:equivalentClass :TouristInformationCenter .
#
# <http://schema.org/TrainStation> a owl:Class ;
#     owl:equivalentClass :TrainStation .
#
# <http://schema.org/amenityFeature> a owl:ObjectProperty ;
#     rdfs:subPropertyOf :hasFeature .
#
# <http://schema.org/audience> a owl:ObjectProperty ;
#     rdfs:subPropertyOf :hasAudience .
#
# <http://schema.org/floorSize> a owl:ObjectProperty ;
#     rdfs:subPropertyOf :hasFloorSize .
#
# ns3:Agent owl:equivalentClass :Agent .
#
# ns3:Organization owl:equivalentClass :Organisation .
#
# ns3:Person owl:equivalentClass :Person .
#
# <https://www.datatourisme.gouv.fr/ontology/core> a owl:Ontology ;
#     ns2:description "National ontology for structuring the tourism data extracted from different systems of tourist information of France in a common sharing format."@en,
#         "Ontologie nationale permettant de structurer les données touristiques extraites des différents systèmes d'informations touristiques de France en un format de diffusion commun."@fr ;
#     ns2:language "EN",
#         "FR" ;
#     ns2:rights "Creative Commons BY-SA - https://creativecommons.org/licenses/by-sa/2.0/fr/legalcode" ;
#     ns2:title "DATAtourisme" ;
#     ns1:contributor "Conjecto - https://www.conjecto.com/",
#         "Ricochets - https://www.ricochets.net/" ;
#     ns1:creator "ADN Tourisme https://www.adn-tourisme.fr/",
#         "Ministère de l'Economie et des Finances/Direction générale des Entreprises - http://www.entreprises.gouv.fr/" ;
#     owl:imports ns2:,
#         <http://purl.org/ontology/olo/core#>,
#         <http://topbraid.org/schema/>,
#         <http://www.ebu.ch/metadata/ontologies/ebucore/ebucore>,
#         <http://www.w3.org/2004/02/skos/core>,
#         ns3: ;
#     owl:versionIRI <https://www.datatourisme.gouv.fr/ontology/core/2.4.4> ;
#     owl:versionInfo "$Date: 2020/10/09 12:03:00 $" .
#
# :ATM a owl:Class ;
#     rdfs:label "ATM"@en,
#         "Distributeur automatique de billets, DAB"@fr ;
#     rdfs:subClassOf :ConvenientService .
#
# :Abbey a owl:Class ;
#     rdfs:label "Abbey"@en,
#         "Abbaye"@fr ;
#     rdfs:subClassOf :ReligiousSite .
#
# :AccommodationFeatureSpecification a owl:Class ;
#     rdfs:label "Accommodation feature specification"@en,
#         "Spécification d'équipement-service d'hébergement"@fr ;
#     rdfs:subClassOf [ a owl:Restriction ;
#             owl:allValuesFrom :AccommodationAmenity ;
#             owl:onProperty :features ],
#         [ a owl:Restriction ;
#             owl:allValuesFrom :AccommodationAmenity ;
#             owl:onProperty :features ],
#         [ a owl:Restriction ;
#             owl:allValuesFrom :AccommodationAmenity ;
#             owl:onProperty :features ],
#         [ a owl:Restriction ;
#             owl:allValuesFrom :AccommodationAmenity ;
#             owl:onProperty :features ],
#         [ a owl:Restriction ;
#             owl:allValuesFrom :AccommodationAmenity ;
#             owl:onProperty :features ],
#         [ a owl:Restriction ;
#             owl:allValuesFrom :AccommodationAmenity ;
#             owl:onProperty :features ],
#         [ a owl:Restriction ;
#             owl:allValuesFrom :AccommodationAmenity ;
#             owl:onProperty :features ],
#         [ a owl:Restriction ;
#             owl:allValuesFrom :AccommodationAmenity ;
#             owl:onProperty :features ],
#         <http://schema.org/LocationFeatureSpecification>,
#         :FeatureSpecification .
#
# :AccommodationPricingOffer a owl:Class ;
#     rdfs:label "Accommodation pricing Offer"@en,
#         "Prestation tarifée d'hébergement"@fr ;
#     rdfs:subClassOf :PricingOffer .
#
# :AccompaniedPractice a owl:Class ;
#     rdfs:label "Accompanied practice"@en,
#         "Accompagnement"@fr ;
#     rdfs:subClassOf :Practice .
#
# :ActivityPricingOffer a owl:Class ;
#     rdfs:label "Activity pricing Offer"@en,
#         "Prestation tarifée d'une activité"@fr ;
#     rdfs:subClassOf :PricingOffer .
#
# :Airfield a owl:Class ;
#     rdfs:label "Airfield"@en,
#         "Aérodrôme"@fr ;
#     rdfs:subClassOf :Transport .
#
# :Airport a owl:Class ;
#     rdfs:label "Airport"@en,
#         "Aéroport"@fr ;
#     rdfs:subClassOf <http://schema.org/Airport>,
#         :Transport .
#
# :AlpinePasture a owl:Class ;
#     rdfs:label "Alpine pasture"@en,
#         "Alpage"@fr ;
#     rdfs:subClassOf :NaturalHeritage .
#
# :AntiqueAndSecondhandGoodDealer a owl:Class ;
#     rdfs:label "Antique and second-hand goods dealer"@en,
#         "Antiquaire et brocanteur"@fr ;
#     rdfs:subClassOf :Store .
#
# :Aqueduct a owl:Class ;
#     rdfs:label "Aqueduct"@en,
#         "Aqueduc"@fr ;
#     rdfs:subClassOf :RemarkableBuilding .
#
# :Arena a owl:Class ;
#     rdfs:label "Arena"@en,
#         "Arène"@fr ;
#     rdfs:subClassOf :RemarkableBuilding .
#
# :ArtGalleryOrExhibitionGallery a owl:Class ;
#     rdfs:label "Art gallery, exhibition gallery"@en,
#         "Galerie d'art, galerie d'exposition"@fr ;
#     rdfs:subClassOf :Store .
#
# :ArtistSigning a owl:Class ;
#     rdfs:label "Artist signing"@en,
#         "Dédicace et rencontre d'artiste"@fr ;
#     rdfs:subClassOf :CulturalEvent .
#
# :Auditorium a owl:Class ;
#     rdfs:label "Auditorium"@en,
#         "Auditorium"@fr ;
#     rdfs:subClassOf :SportsAndLeisurePlace .
#
# :Bakery a owl:Class ;
#     rdfs:label "Bakery"@en,
#         "Boulangerie"@fr ;
#     rdfs:subClassOf <http://schema.org/Bakery>,
#         :FoodEstablishment .
#
# :BalneotherapyCentre a owl:Class ;
#     rdfs:label "Balneotherapy centre"@en,
#         "Centre de balnéothérapie"@fr ;
#     rdfs:subClassOf :SportsAndLeisurePlace .
#
# :BarOrPub a owl:Class ;
#     rdfs:label "Bar or theme bar"@en,
#         "Bar, bar à thème"@fr ;
#     rdfs:subClassOf :FoodEstablishment .
#
# :Basilica a owl:Class ;
#     rdfs:label "Basilica"@en,
#         "Basilique"@fr ;
#     rdfs:subClassOf :ReligiousSite .
#
# :Bastide a owl:Class ;
#     rdfs:label "Bastide"@en,
#         "Bastide"@fr ;
#     rdfs:subClassOf :CityHeritage .
#
# :Beach a owl:Class ;
#     rdfs:label "Beach"@en,
#         "Plage"@fr ;
#     rdfs:subClassOf :NaturalHeritage .
#
# :BeachClub a owl:Class ;
#     rdfs:label "Beach club"@en,
#         "Club de plage"@fr ;
#     rdfs:subClassOf <http://schema.org/LocalBusiness>,
#         :SportsAndLeisurePlace .
#
# :Bed a owl:Class ;
#     rdfs:label "Bed"@en,
#         "Lit"@fr ;
#     rdfs:subClassOf :AccommodationProduct .
#
# :BikeStationOrDepot a owl:Class ;
#     rdfs:label "Bike station or depot"@en,
#         "Station ou dépôt de vélo"@fr ;
#     rdfs:subClassOf :Transport .
#
# :BilliardRoom a owl:Class ;
#     rdfs:label "Billiard room"@en,
#         "Salle de billard"@fr ;
#     rdfs:subClassOf <http://schema.org/LocalBusiness>,
#         :SportsAndLeisurePlace .
#
# :Bishopric a owl:Class ;
#     rdfs:label "Bishopric"@en,
#         "Evéché"@fr ;
#     rdfs:subClassOf :ReligiousSite .
#
# :BistroOrWineBar a owl:Class ;
#     rdfs:label "Bistro - Wine bar"@en,
#         "Bistrot - Bar à vin"@fr ;
#     rdfs:subClassOf <http://schema.org/Winery>,
#         :FoodEstablishment .
#
# :BoardMeeting a owl:Class ;
#     rdfs:label "Board meeting"@en,
#         "Conseil d'administration"@fr ;
#     rdfs:subClassOf :BusinessEvent .
#
# :BoatRestaurant a owl:Class ;
#     rdfs:label "Boat restaurant"@en,
#         "Bateau-restaurant"@fr ;
#     rdfs:subClassOf :Restaurant .
#
# :Bocage a owl:Class ;
#     rdfs:label "Bocage"@en,
#         "Bocage"@fr ;
#     rdfs:subClassOf :NaturalHeritage .
#
# :Bog a owl:Class ;
#     rdfs:label "Bog"@en,
#         "Tourbière"@fr ;
#     rdfs:subClassOf :NaturalHeritage .
#
# :BoulesPitch a owl:Class ;
#     rdfs:label "Boules pitch"@en,
#         "Boulodrome"@fr ;
#     rdfs:subClassOf <http://schema.org/LocalBusiness>,
#         :SportsAndLeisurePlace .
#
# :BoutiqueOrLocalShop a owl:Class ;
#     rdfs:label "Boutique or local shop"@en,
#         "Boutique, commerce de proximité"@fr ;
#     rdfs:subClassOf :Store .
#
# :BowlingAlley a owl:Class ;
#     rdfs:label "Bowling alley"@en,
#         "Bowling"@fr ;
#     rdfs:subClassOf :SportsAndLeisurePlace .
#
# :BrasserieOrTavern a owl:Class ;
#     rdfs:label "Brasserie or tavern"@en,
#         "Brasserie ou taverne"@fr ;
#     rdfs:subClassOf :Restaurant .
#
# :Brewery a owl:Class ;
#     rdfs:label "Brewery"@en,
#         "Brasseur"@fr ;
#     rdfs:subClassOf :TastingProvider .
#
# :BricABrac a owl:Class ;
#     rdfs:label "Bric-a-brac"@en,
#         "Brocante"@fr ;
#     rdfs:subClassOf <http://schema.org/SaleEvent>,
#         :SaleEvent .
#
# :Bridge a owl:Class ;
#     rdfs:label "Bridge"@en,
#         "Pont"@fr ;
#     rdfs:subClassOf :RemarkableBuilding .
#
# :Bubble a owl:Class ;
#     rdfs:label "Bubble"@en,
#         "Bulle"@fr ;
#     rdfs:subClassOf :AccommodationProduct .
#
# :BuddhistTemple a owl:Class ;
#     rdfs:label "Buddhist temple"@en,
#         "Temple bouddhique"@fr ;
#     rdfs:subClassOf :ReligiousSite .
#
# :Bungalow a owl:Class ;
#     rdfs:label "Bungalow"@en,
#         "Bungalow, Mobil Home"@fr ;
#     rdfs:subClassOf :AccommodationProduct .
#
# :Bungatoile a owl:Class ;
#     rdfs:label "Bungatoile"@en,
#         "Bungatoile"@fr ;
#     rdfs:subClassOf :AccommodationProduct .
#
# :COVID19InOperationConfirmed a owl:DatatypeProperty,
#         owl:FunctionalProperty ;
#     rdfs:label "Is in operation"@en,
#         "Est en activité"@fr ;
#     rdfs:comment "Site in total or partial activity, as opposed to temporarily closed."@en,
#         "Site en activité totale ou partielle, contraire de temporairement fermé."@fr ;
#     rdfs:domain :PointOfInterest ;
#     rdfs:range xsd:boolean ;
#     :hasPriority "9.2"^^xsd:float .
#
# :COVID19OpeningPeriodsConfirmed a owl:DatatypeProperty,
#         owl:FunctionalProperty ;
#     rdfs:label "Confirmed opening periods – COVID19 unconfinement"@en,
#         "Périodes d'ouvertures confirmées – déconfinement COVID19"@fr ;
#     rdfs:domain :PointOfInterest ;
#     rdfs:range xsd:boolean ;
#     :hasPriority "9.1"^^xsd:float .
#
# :COVID19SpecialMeasures a owl:DatatypeProperty ;
#     rdfs:label "has these special measures Covid-19"@en,
#         "a comme mesures spécifiques Covid-19"@fr ;
#     rdfs:comment "Special arrangements made by the company or site manager, e.g. exceptional arrangements for receiving the public or the provision of appropriate services and facilities."@en,
#         "Dispositions spéciales prises par l’entreprise ou le gestionnaire du site, par exemple les modalités exceptionnelles d’accueil du public ou la fourniture des services et prestations adaptées."@fr ;
#     rdfs:domain :PointOfInterest ;
#     rdfs:range rdf:langString ;
#     :hasPriority 9.3 .
#
# :Cabaret a owl:Class ;
#     rdfs:label "Cabaret"@en,
#         "Cabaret"@fr ;
#     rdfs:subClassOf :Restaurant .
#
# :CableCarStation a owl:Class ;
#     rdfs:label "Cable car station"@en,
#         "Téléphérique"@fr ;
#     rdfs:subClassOf :Transport .
#
# :CafeOrTeahouse a owl:Class ;
#     rdfs:label "Coffee or tea house"@en,
#         "Café ou salon de thé"@fr ;
#     rdfs:subClassOf <http://schema.org/CafeOrCoffeeShop>,
#         :FoodEstablishment .
#
# :Calvary a owl:Class ;
#     rdfs:label "Calvary and parish enclosures"@en,
#         "Calvaire et enclos paroissiaux"@fr ;
#     rdfs:subClassOf :ReligiousSite .
#
# :CamperVanArea a owl:Class ;
#     rdfs:label "Camper van area"@en,
#         "Aire de camping-car"@fr ;
#     rdfs:subClassOf :CampingAndCaravanning .
#
# :Camping a owl:Class ;
#     rdfs:label "Campsite"@en,
#         "Camping"@fr ;
#     rdfs:subClassOf :CampingAndCaravanning .
#
# :CampingCar a owl:Class ;
#     rdfs:label "Camping car"@en,
#         "Camping car"@fr ;
#     rdfs:subClassOf :AccommodationProduct .
#
# :CampingPitch a owl:Class ;
#     rdfs:label "Camping pitch"@en,
#         "Emplacement de camping"@fr ;
#     rdfs:subClassOf <http://schema.org/CampingPitch>,
#         :AccommodationProduct .
#
# :Canal a owl:Class ;
#     rdfs:label "Canal"@en,
#         "Canal"@fr ;
#     rdfs:subClassOf :NaturalHeritage .
#
# :Canyon a owl:Class ;
#     rdfs:label "Canyon"@en,
#         "Canyon"@fr ;
#     rdfs:subClassOf :NaturalHeritage .
#
# :CarOrBikeWash a owl:Class ;
#     rdfs:label "Car or bike wash"@en,
#         "Station de lavage"@fr ;
#     rdfs:subClassOf :ConvenientService .
#
# :Caravan a owl:Class ;
#     rdfs:label "Caravan"@en,
#         "Caravane"@fr ;
#     rdfs:subClassOf :AccommodationProduct .
#
# :Carnival a owl:Class ;
#     rdfs:label "Carnival"@en,
#         "Carnaval"@fr ;
#     rdfs:subClassOf :SocialEvent .
#
# :CarpoolArea a owl:Class ;
#     rdfs:label "Carpool area"@en,
#         "Aire de covoiturage"@fr ;
#     rdfs:subClassOf :Transport .
#
# :Casino a owl:Class ;
#     rdfs:label "Casino"@en,
#         "Casino"@fr ;
#     rdfs:subClassOf <http://schema.org/Casino>,
#         :SportsAndLeisurePlace .
#
# :Castle a owl:Class ;
#     rdfs:label "Castle"@en,
#         "Château"@fr ;
#     rdfs:subClassOf :RemarkableBuilding .
#
# :CastleAndPrestigeMansion a owl:Class ;
#     rdfs:label "Castle and prestige mansion"@en,
#         "Château et demeure de prestige"@fr ;
#     rdfs:subClassOf :AccommodationProduct .
#
# :CateringPricingOffer a owl:Class ;
#     rdfs:label "Catering pricing Offer"@en,
#         "Prestation tarifée de restauration"@fr ;
#     rdfs:subClassOf :PricingOffer .
#
# :Cathedral a owl:Class ;
#     rdfs:label "Cathedral"@en,
#         "Cathédrale"@fr ;
#     rdfs:subClassOf :ReligiousSite .
#
# :Causse a owl:Class ;
#     rdfs:label "Causse"@en,
#         "Causse"@fr ;
#     rdfs:subClassOf :NaturalHeritage .
#
# :CaveSinkholeOrAven a owl:Class ;
#     rdfs:label "Cave, sinkhole, aven"@en,
#         "Grotte, gouffre, aven, caverne, carrière"@fr ;
#     rdfs:subClassOf :NaturalHeritage .
#
# :Cellar a owl:Class ;
#     rdfs:label "Cellar"@en,
#         "Cave ou caveau"@fr ;
#     rdfs:subClassOf :FoodEstablishment .
#
# :Chalet a owl:Class ;
#     rdfs:label "Chalet"@en,
#         "Chalet"@fr ;
#     rdfs:subClassOf :AccommodationProduct .
#
# :ChalkyLawn a owl:Class ;
#     rdfs:label "Chalky lawn"@en,
#         "Pelouse calcaire"@fr ;
#     rdfs:subClassOf :NaturalHeritage .
#
# :ChamberOfCommerceAndIndustry a owl:Class ;
#     rdfs:label "Chamber of commerce and industry"@en,
#         "Chambre de commerce et d'industrie"@fr ;
#     rdfs:subClassOf :BusinessPlace .
#
# :Chapel a owl:Class ;
#     rdfs:label "Chapel"@en,
#         "Chapelle"@fr ;
#     rdfs:subClassOf :ReligiousSite .
#
# :Chartreuse a owl:Class ;
#     rdfs:label "Chartreuse"@en,
#         "Chartreuse"@fr ;
#     rdfs:subClassOf :RemarkableBuilding .
#
# :ChildrensEvent a owl:Class ;
#     rdfs:label "Children event"@en,
#         "Evènement jeune public"@fr ;
#     rdfs:subClassOf :CulturalEvent .
#
# :ChildrensGite a owl:Class ;
#     rdfs:label "Children gite"@en,
#         "Gîte d'enfants"@fr ;
#     rdfs:subClassOf :CollectiveAccommodation .
#
# :Church a owl:Class ;
#     rdfs:label "Church"@en,
#         "Eglise"@fr ;
#     rdfs:subClassOf :ReligiousSite .
#
# :Cinema a owl:Class ;
#     rdfs:label "Cinema"@en,
#         "Cinéma"@fr ;
#     rdfs:subClassOf <http://schema.org/MovieTheater>,
#         :SportsAndLeisurePlace .
#
# :Cinematheque a owl:Class ;
#     rdfs:label "Cinematheque"@en,
#         "Cinémathèque"@fr ;
#     rdfs:subClassOf :SportsAndLeisurePlace .
#
# :CircusEvent a owl:Class ;
#     rdfs:label "Circus event"@en,
#         "Spectacle de cirque"@fr ;
#     rdfs:subClassOf :CulturalEvent .
#
# :CircusPlace a owl:Class ;
#     rdfs:label "Circus"@en,
#         "Cirque"@fr ;
#     rdfs:comment "The circus as a building. E.g \"Winter circus\", Cirque d'hiver of Paris"@en,
#         "Le cirque en tant que bâtiment en dur. Ex: le Cirque d'hiver de Paris."@fr ;
#     rdfs:subClassOf :SportsAndLeisurePlace .
#
# :Cirque a owl:Class ;
#     rdfs:label "Cirque"@en,
#         "Cirque naturel"@fr ;
#     rdfs:subClassOf :NaturalHeritage .
#
# :Citadel a owl:Class ;
#     rdfs:label "Citadel"@en,
#         "Citadelle"@fr ;
#     rdfs:subClassOf :DefenceSite .
#
# :CivilCemetery a owl:Class ;
#     rdfs:label "Civil cemetery"@en,
#         "Cimetière civil"@fr ;
#     rdfs:subClassOf :RemembranceSite .
#
# :Cliff a owl:Class ;
#     rdfs:label "Cliff"@en,
#         "Falaise"@fr ;
#     rdfs:subClassOf :NaturalHeritage .
#
# :ClimbingWall a owl:Class ;
#     rdfs:label "Climbing wall"@en,
#         "Site et mur d'escalade"@fr ;
#     rdfs:subClassOf :SportsAndLeisurePlace .
#
# :Cloister a owl:Class ;
#     rdfs:label "Cloister"@en,
#         "Cloître"@fr ;
#     rdfs:subClassOf :ReligiousSite .
#
# :ClubOrHolidayVillage a owl:Class ;
#     rdfs:label "Club or holiday village"@en,
#         "Club et village vacances"@fr ;
#     rdfs:subClassOf :CollectiveAccommodation .
#
# :Coastline a owl:Class ;
#     rdfs:label "Coastline"@en,
#         "Côte, littoral"@fr ;
#     rdfs:subClassOf :NaturalHeritage .
#
# :Col a owl:Class ;
#     rdfs:label "Col"@en,
#         "Col"@fr ;
#     rdfs:subClassOf :NaturalHeritage .
#
# :Collegiate a owl:Class ;
#     rdfs:label "Collegiate"@en,
#         "Collégiale"@fr ;
#     rdfs:subClassOf :ReligiousSite .
#
# :Commanderie a owl:Class ;
#     rdfs:label "Commanderie"@en,
#         "Commanderie"@fr ;
#     rdfs:subClassOf :ReligiousSite .
#
# :Commemoration a owl:Class ;
#     rdfs:label "Commemoration"@en,
#         "Commémoration"@fr ;
#     rdfs:subClassOf :CulturalEvent .
#
# :Competition a owl:Class ;
#     rdfs:label "Competition"@en,
#         "Compétition"@fr ;
#     rdfs:subClassOf :Practice .
#
# :Concert a owl:Class ;
#     rdfs:label "Concert"@en,
#         "Concert"@fr ;
#     rdfs:subClassOf <http://schema.org/MusicEvent>,
#         :CulturalEvent .
#
# :ConeNeck a owl:Class ;
#     rdfs:label "Cone / neck"@en,
#         "Cône"@fr ;
#     rdfs:subClassOf :NaturalHeritage .
#
# :Conference a owl:Class ;
#     rdfs:label "Conference"@en,
#         "Conférence"@fr ;
#     rdfs:subClassOf :CulturalEvent .
#
# :Congress a owl:Class ;
#     rdfs:label "Congress"@en,
#         "Congrès"@fr ;
#     rdfs:subClassOf :BusinessEvent .
#
# :Convent a owl:Class ;
#     rdfs:label "Convent"@en,
#         "Couvent"@fr ;
#     rdfs:subClassOf :ReligiousSite .
#
# :ConventionCentre a owl:Class ;
#     rdfs:label "Convention centre"@en,
#         "Centre de congrès"@fr ;
#     rdfs:subClassOf :BusinessPlace .
#
# :Cooperative a owl:Class ;
#     rdfs:label "Cooperative"@en,
#         "Coopérative"@fr ;
#     rdfs:subClassOf :TastingProvider .
#
# :Course a owl:Class ;
#     rdfs:label "Course"@en,
#         "Cours"@fr ;
#     rdfs:subClassOf :Practice .
#
# :CoveredMarket a owl:Class ;
#     rdfs:label "Covered market"@en,
#         "Halle, marché couvert"@fr ;
#     rdfs:subClassOf :TechnicalHeritage .
#
# :CraftsmanShop a owl:Class ;
#     rdfs:label "Craftsman shop"@en,
#         "Artisan d'art"@fr ;
#     rdfs:subClassOf :Store .
#
# :Crest a owl:Class ;
#     rdfs:label "Crest"@en,
#         "Crête"@fr ;
#     rdfs:subClassOf :NaturalHeritage .
#
# :CrossCountrySkiResort a owl:Class ;
#     rdfs:label "Cross-country ski resort"@en,
#         "Domaine de ski nordique"@fr ;
#     rdfs:subClassOf :SportsAndLeisurePlace .
#
# :CrossCountrySkiTrail a owl:Class ;
#     rdfs:label "Cross-country ski trail"@en,
#         "Piste de ski de fond"@fr ;
#     rdfs:subClassOf :SportsAndLeisurePlace .
#
# :Cuesta a owl:Class ;
#     rdfs:label "Cuesta"@en,
#         "Cuesta"@fr ;
#     rdfs:subClassOf :NaturalHeritage .
#
# :CulturalActivityProvider a owl:Class ;
#     rdfs:label "Cultural activity provider"@en,
#         "Prestataire d'activité culturelle"@fr ;
#     rdfs:subClassOf :ActivityProvider .
#
# :CulturalHeritageFeatureSpecification a owl:Class ;
#     rdfs:label "Cultural heritage feature specification"@en,
#         "Spécification d'équipement de patrimoine culturel"@fr ;
#     rdfs:subClassOf [ a owl:Restriction ;
#             owl:allValuesFrom :CulturalHeritageAmenity ;
#             owl:onProperty :features ],
#         [ a owl:Restriction ;
#             owl:allValuesFrom :CulturalHeritageAmenity ;
#             owl:onProperty :features ],
#         [ a owl:Restriction ;
#             owl:allValuesFrom :CulturalHeritageAmenity ;
#             owl:onProperty :features ],
#         [ a owl:Restriction ;
#             owl:allValuesFrom :CulturalHeritageAmenity ;
#             owl:onProperty :features ],
#         [ a owl:Restriction ;
#             owl:allValuesFrom :CulturalHeritageAmenity ;
#             owl:onProperty :features ],
#         [ a owl:Restriction ;
#             owl:allValuesFrom :CulturalHeritageAmenity ;
#             owl:onProperty :features ],
#         [ a owl:Restriction ;
#             owl:allValuesFrom :CulturalHeritageAmenity ;
#             owl:onProperty :features ],
#         [ a owl:Restriction ;
#             owl:allValuesFrom :CulturalHeritageAmenity ;
#             owl:onProperty :features ],
#         :FeatureSpecification .
#
# :CulturalTheme a owl:Class ;
#     rdfs:label "Cultural"@en,
#         "Culture"@fr ;
#     rdfs:subClassOf :Theme .
#
# :Culture a owl:Class ;
#     rdfs:label "Culture"@en,
#         "Culture"@fr ;
#     rdfs:subClassOf :NaturalHeritage .
#
# :Cybercafe a owl:Class ;
#     rdfs:label "Cybercafe"@en,
#         "Cybercafé"@fr ;
#     rdfs:subClassOf :ConvenientService .
#
# :CycleRouteTheme a owl:Class ;
#     rdfs:label "Cycle route name"@en,
#         "Itinéraire vélo route"@fr ;
#     rdfs:subClassOf :RouteTheme .
#
# :CyclingTour a owl:Class ;
#     rdfs:label "Cycling route"@en,
#         "Itinéraire cyclable"@fr ;
#     rdfs:subClassOf :Tour .
#
# :DepartementTourismCommittee a owl:Class ;
#     rdfs:label "Département tourism committee"@en,
#         "Comité départemental du tourisme"@fr ;
#     rdfs:subClassOf :TouristInformationCenter .
#
# :DepartmentStore a owl:Class ;
#     rdfs:label "Department store"@en,
#         "Grand magasin"@fr ;
#     rdfs:subClassOf :Store .
#
# :DevelopmentCourse a owl:Class ;
#     rdfs:label "Development course"@en,
#         "Stage de perfectionnement"@fr ;
#     rdfs:subClassOf :Practice .
#
# :District a owl:Class ;
#     rdfs:label "District"@en,
#         "Quartier"@fr ;
#     rdfs:subClassOf :CityHeritage .
#
# :DogSleddingTrail a owl:Class ;
#     rdfs:label "Dog sledding trail"@en,
#         "Piste de chien de traineau"@fr ;
#     rdfs:subClassOf :SportsAndLeisurePlace .
#
# :DownhillSkiResort a owl:Class ;
#     rdfs:label "Downhill ski resort"@en,
#         "Domaine de ski alpin"@fr ;
#     rdfs:subClassOf :SportsAndLeisurePlace .
#
# :DownhillSkiRun a owl:Class ;
#     rdfs:label "Downhill ski run"@en,
#         "Piste de ski alpin"@fr ;
#     rdfs:subClassOf :SportsAndLeisurePlace .
#
# :Dune a owl:Class ;
#     rdfs:label "Dune"@en,
#         "Dune"@fr ;
#     rdfs:subClassOf :NaturalHeritage .
#
# :Dungeon a owl:Class ;
#     rdfs:label "Dungeon"@en,
#         "Donjon"@fr ;
#     rdfs:subClassOf :DefenceSite .
#
# :EducationalTrail a owl:Class ;
#     rdfs:label "Educational trail"@en,
#         "Sentier de découverte et d'interprétation"@fr ;
#     rdfs:subClassOf :SportsAndLeisurePlace .
#
# :ElectricVehicleChargingPoint a owl:Class ;
#     rdfs:label "Electric vehicle charging point"@en,
#         "Borne de charge véhicule électrique"@fr ;
#     rdfs:subClassOf :ConvenientService .
#
# :EntertainmentAndEventTheme a owl:Class ;
#     rdfs:label "Entertainment and event theme"@en,
#         "Thème de fête et évènement"@fr ;
#     rdfs:subClassOf :Theme .
#
# :EquestrianCenter a owl:Class ;
#     rdfs:label "Equestrian center"@en,
#         "Centre équestre"@fr ;
#     rdfs:subClassOf <http://schema.org/LocalBusiness>,
#         :SportsAndLeisurePlace .
#
# :EquipmentRental a owl:Class ;
#     rdfs:label "Equipment rental"@en,
#         "Location de matériel"@fr ;
#     rdfs:subClassOf [ a owl:Restriction ;
#             owl:allValuesFrom :CommonFeatureSpecification ;
#             owl:onProperty :hasFeature ],
#         [ a owl:Restriction ;
#             owl:allValuesFrom :CommonFeatureSpecification ;
#             owl:onProperty :hasFeature ],
#         [ a owl:Restriction ;
#             owl:allValuesFrom :CommonFeatureSpecification ;
#             owl:onProperty :hasFeature ],
#         [ a owl:Restriction ;
#             owl:allValuesFrom :CommonFeatureSpecification ;
#             owl:onProperty :hasFeature ],
#         [ a owl:Restriction ;
#             owl:allValuesFrom :CommonFeatureSpecification ;
#             owl:onProperty :hasFeature ],
#         [ a owl:Restriction ;
#             owl:allValuesFrom :CommonFeatureSpecification ;
#             owl:onProperty :hasFeature ],
#         [ a owl:Restriction ;
#             owl:allValuesFrom :CommonFeatureSpecification ;
#             owl:onProperty :hasFeature ],
#         [ a owl:Restriction ;
#             owl:allValuesFrom :CommonFeatureSpecification ;
#             owl:onProperty :hasFeature ],
#         :Rental .
#
# :EquipmentRentalShop a owl:Class ;
#     rdfs:label "Equipment rental shop"@en,
#         "Loueur de matériel"@fr ;
#     rdfs:subClassOf :ServiceProvider .
#
# :EquipmentRepairShop a owl:Class ;
#     rdfs:label "Equipment repair shop"@en,
#         "Réparateur de matériel"@fr ;
#     rdfs:subClassOf :ServiceProvider .
#
# :ExecutiveBoardMeeting a owl:Class ;
#     rdfs:label "Executive board meeting"@en,
#         "Bureau éxécutif"@fr ;
#     rdfs:subClassOf :BusinessEvent .
#
# :FairOrShow a owl:Class ;
#     rdfs:label "Fair or show"@en,
#         "Foire ou salon"@fr ;
#     rdfs:subClassOf <http://schema.org/SaleEvent>,
#         :SaleEvent .
#
# :Farm a owl:Class ;
#     rdfs:label "Farm"@en,
#         "Ferme"@fr ;
#     rdfs:subClassOf :TechnicalHeritage .
#
# :Farmer a owl:Class ;
#     rdfs:label "Farmer"@en,
#         "Éleveur"@fr ;
#     rdfs:subClassOf :TastingProvider .
#
# :FarmhouseInn a owl:Class ;
#     rdfs:label "Farmhouse inn"@en,
#         "Ferme et auberge de campagne"@fr ;
#     rdfs:subClassOf :Restaurant .
#
# :FirstPractice a owl:Class ;
#     rdfs:label "First practice"@en,
#         "Baptême sportif"@fr ;
#     rdfs:subClassOf :Practice .
#
# :FitnessCenter a owl:Class ;
#     rdfs:label "Fitness centre"@en,
#         "Centre de remise en forme - fitness"@fr ;
#     rdfs:subClassOf <http://schema.org/LocalBusiness>,
#         :SportsAndLeisurePlace .
#
# :FitnessPath a owl:Class ;
#     rdfs:label "Fitness path"@en,
#         "Parcours de Santé"@fr ;
#     rdfs:subClassOf <http://schema.org/CivicStructure>,
#         :SportsAndLeisurePlace .
#
# :FluvialTour a owl:Class ;
#     rdfs:label "Fluvial or sea route"@en,
#         "Itinéraire fluvial ou maritime"@fr ;
#     rdfs:subClassOf :Tour .
#
# :FoodEstablishmentTheme a owl:Class ;
#     rdfs:label "Food establishment theme"@en,
#         "Thème de restauration"@fr ;
#     rdfs:subClassOf :Theme .
#
# :Forest a owl:Class ;
#     rdfs:label "Forest"@en,
#         "Forêt"@fr ;
#     rdfs:subClassOf :NaturalHeritage .
#
# :Forge a owl:Class ;
#     rdfs:label "Forge"@en,
#         "Forge"@fr ;
#     rdfs:subClassOf :TechnicalHeritage .
#
# :Fort a owl:Class ;
#     rdfs:label "Fort"@en,
#         "Fort"@fr ;
#     rdfs:subClassOf :DefenceSite .
#
# :FortifiedCastle a owl:Class ;
#     rdfs:label "Fortified castle"@en,
#         "Château fort"@fr ;
#     rdfs:subClassOf :DefenceSite .
#
# :FortifiedSet a owl:Class ;
#     rdfs:label "Fortified set"@en,
#         "Ensemble fortifié"@fr ;
#     rdfs:subClassOf :DefenceSite .
#
# :Fountain a owl:Class ;
#     rdfs:label "Fountain"@en,
#         "Fontaine"@fr ;
#     rdfs:subClassOf :RemarkableBuilding .
#
# :FreePractice a owl:Class ;
#     rdfs:label "Free practice"@en,
#         "Pratique libre"@fr ;
#     rdfs:subClassOf :Practice .
#
# :FrontonBelotaCourt a owl:Class ;
#     rdfs:label "Fronton, belota court"@en,
#         "Fronton, mur de frappe"@fr ;
#     rdfs:subClassOf :SportsAndLeisurePlace .
#
# :GPX a owl:Class ;
#     rdfs:label "GPX document"@en,
#         "Document GPX"@fr ;
#     rdfs:subClassOf <http://www.ebu.ch/metadata/ontologies/ebucore/ebucore#BusinessObject> .
#
# :Game a owl:Class ;
#     rdfs:label "Game, contest"@en,
#         "Jeu, concours"@fr ;
#     rdfs:subClassOf <http://schema.org/SportsEvent>,
#         :SportsEvent .
#
# :GarageOrAirPump a owl:Class ;
#     rdfs:label "Garage or air pump"@en,
#         "Borne ou station de réparation - gonflage"@fr ;
#     rdfs:subClassOf :ConvenientService .
#
# :GarageSale a owl:Class ;
#     rdfs:label "Garage sale"@en,
#         "Vide-grenier"@fr ;
#     rdfs:subClassOf <http://schema.org/SaleEvent>,
#         :SaleEvent .
#
# :GeneralPricingOffer a owl:Class ;
#     rdfs:label "General pricing Offer"@en,
#         "Prestation tarifée générale"@fr ;
#     rdfs:subClassOf :PricingOffer .
#
# :Glacier a owl:Class ;
#     rdfs:label "Glacier"@en,
#         "Glacier de montagne"@fr ;
#     rdfs:subClassOf :NaturalHeritage .
#
# :Gorge a owl:Class ;
#     rdfs:label "Gorge"@en,
#         "Gorge"@fr ;
#     rdfs:subClassOf :NaturalHeritage .
#
# :GourmetRestaurant a owl:Class ;
#     rdfs:label "Gourmet restaurant"@en,
#         "Restaurant gastronomique"@fr ;
#     rdfs:subClassOf :Restaurant .
#
# :Grassland a owl:Class ;
#     rdfs:label "Grassland"@en,
#         "Prairie"@fr ;
#     rdfs:subClassOf :NaturalHeritage .
#
# :GroupLodging a owl:Class ;
#     rdfs:label "Group lodging"@en,
#         "Gîte de groupe"@fr ;
#     rdfs:subClassOf :CollectiveAccommodation .
#
# :Gymnasium a owl:Class ;
#     rdfs:label "Gymnasium or sports field"@en,
#         "Salle ou terrain de sport, gymnase"@fr ;
#     rdfs:subClassOf :SportsAndLeisurePlace .
#
# :HalophilicArea a owl:Class ;
#     rdfs:label "HalophilicArea"@en,
#         "Zone halophile"@fr ;
#     rdfs:subClassOf :NaturalHeritage .
#
# :Hammam a owl:Class ;
#     rdfs:label "Hammam"@en,
#         "Hammam"@fr ;
#     rdfs:subClassOf :SportsAndLeisurePlace .
#
# :Harvest a owl:Class ;
#     rdfs:label "Harvest"@en,
#         "Vendange, récolte"@fr ;
#     rdfs:subClassOf :CulturalEvent .
#
# :HealthTheme a owl:Class ;
#     rdfs:label "Health theme"@en,
#         "Thème de santé"@fr ;
#     rdfs:subClassOf :Theme .
#
# :HealthcarePlace a owl:Class ;
#     rdfs:label "Healthcare place"@en,
#         "Lieu de soins"@fr ;
#     rdfs:comment "A place where someone can receive healthcare (a hospital, a clinic, ...)"@en,
#         "Un lieu où l'on peut recevoir des soins (hôpital, clinique, ...)."@fr ;
#     rdfs:subClassOf :MedicalPlace .
#
# :HealthcareProfessional a owl:Class ;
#     rdfs:label "Healthcare professionnal"@en,
#         "Professionnel de santé"@fr ;
#     rdfs:subClassOf :MedicalPlace .
#
# :Hillsides a owl:Class ;
#     rdfs:label "Hillsides"@en,
#         "Côteau"@fr ;
#     rdfs:subClassOf :NaturalHeritage .
#
# :HolidayCentre a owl:Class ;
#     rdfs:label "Holiday centre"@en,
#         "Centre de vacances et de loisirs"@fr ;
#     rdfs:subClassOf <http://schema.org/Hostel>,
#         :CollectiveAccommodation .
#
# :HolidayResort a owl:Class ;
#     rdfs:label "Holiday resort"@en,
#         "Résidence de tourisme"@fr ;
#     rdfs:subClassOf :CollectiveAccommodation .
#
# :HorseTour a owl:Class ;
#     rdfs:label "Horse route"@en,
#         "Itinéraire équestre"@fr ;
#     rdfs:subClassOf :Tour .
#
# :HotelRestaurant a owl:Class ;
#     rdfs:label "Hotel restaurant"@en,
#         "Hôtel-restaurant"@fr ;
#     rdfs:subClassOf :Hotel,
#         :Restaurant .
#
# :HouseBoat a owl:Class ;
#     rdfs:label "House boat"@en,
#         "Bâteau habitable"@fr ;
#     rdfs:subClassOf :AccommodationProduct .
#
# :Hut a owl:Class ;
#     rdfs:label "Hut"@en,
#         "Cabane"@fr ;
#     rdfs:subClassOf :AccommodationProduct .
#
# :HypermarketAndSupermarket a owl:Class ;
#     rdfs:label "Hypermarket and supermarket"@en,
#         "Grande et moyenne surface"@fr ;
#     rdfs:subClassOf :Store .
#
# :IceSkatingRink a owl:Class ;
#     rdfs:label "Ice skating rink"@en,
#         "Patinoire"@fr ;
#     rdfs:subClassOf <http://schema.org/LocalBusiness>,
#         :SportsAndLeisurePlace .
#
# :Icefall a owl:Class ;
#     rdfs:label "Icefall"@en,
#         "Cascade de glace"@fr ;
#     rdfs:subClassOf :NaturalHeritage .
#
# :IncomingTravelAgency a owl:Class ;
#     rdfs:label "Incoming travel agency"@en,
#         "Organisme réceptif"@fr ;
#     rdfs:subClassOf :TouristInformationCenter .
#
# :IndustrialSite a owl:Class ;
#     rdfs:label "Industrial site"@en,
#         "Site industriel"@fr ;
#     rdfs:subClassOf :TechnicalHeritage .
#
# :InterpretationCentre a owl:Class ;
#     rdfs:label "Interpretation centre"@en,
#         "Centre d'interprétation"@fr ;
#     rdfs:subClassOf <http://schema.org/LocalBusiness>,
#         :CulturalSite .
#
# :IntroductionCourse a owl:Class ;
#     rdfs:label "Introduction course"@en,
#         "Stage d'initiation"@fr ;
#     rdfs:subClassOf :Practice .
#
# :IslandPeninsula a owl:Class ;
#     rdfs:label "Island peninsula"@en,
#         "Ile - presqu'île"@fr ;
#     rdfs:subClassOf :NaturalHeritage .
#
# :Jetty a owl:Class ;
#     rdfs:label "Jetty"@en,
#         "Embarcadère"@fr ;
#     rdfs:subClassOf :SportsAndLeisurePlace .
#
# :KML a owl:Class ;
#     rdfs:label "KML document"@en,
#         "Document KML"@fr ;
#     rdfs:subClassOf <http://www.ebu.ch/metadata/ontologies/ebucore/ebucore#BusinessObject> .
#
# :KidsClub a owl:Class ;
#     rdfs:label "Kid's club"@en,
#         "Club enfants"@fr ;
#     rdfs:subClassOf <http://schema.org/LocalBusiness>,
#         :SportsAndLeisurePlace .
#
# :LabelReview a owl:Class ;
#     rdfs:label "Label review"@en,
#         "Classement par label"@fr ;
#     rdfs:comment "A review that associates a a Product with the value of  a LabelReviewSystem (a LabelRating). e.g. \"Plus beau Village de France\"."@en,
#         "Un classement qui associe un Produit avec la valeur d'un label issue d'un LabelReviewSystem (un LabelRating). ex: \"Plus beau village de France\"."@fr ;
#     rdfs:subClassOf [ a owl:Restriction ;
#             owl:allValuesFrom :LabelRating ;
#             owl:onProperty :hasReviewValue ],
#         [ a owl:Restriction ;
#             owl:allValuesFrom :LabelRating ;
#             owl:onProperty :hasReviewValue ],
#         [ a owl:Restriction ;
#             owl:allValuesFrom :LabelRating ;
#             owl:onProperty :hasReviewValue ],
#         [ a owl:Restriction ;
#             owl:allValuesFrom :LabelRating ;
#             owl:onProperty :hasReviewValue ],
#         [ a owl:Restriction ;
#             owl:allValuesFrom :LabelRating ;
#             owl:onProperty :hasReviewValue ],
#         [ a owl:Restriction ;
#             owl:allValuesFrom :LabelRating ;
#             owl:onProperty :hasReviewValue ],
#         [ a owl:Restriction ;
#             owl:allValuesFrom :LabelRating ;
#             owl:onProperty :hasReviewValue ],
#         [ a owl:Restriction ;
#             owl:allValuesFrom :LabelRating ;
#             owl:onProperty :hasReviewValue ],
#         :Review ;
#     owl:disjointWith :ScaleReview .
#
# :Lake a owl:Class ;
#     rdfs:label "Lake"@en,
#         "Lac"@fr ;
#     rdfs:subClassOf :NaturalHeritage .
#
# :Landes a owl:Class ;
#     rdfs:label "Landes"@en,
#         "Landes"@fr ;
#     rdfs:subClassOf :NaturalHeritage .
#
# :LaunchingRamp a owl:Class ;
#     rdfs:label "Launching ramp"@en,
#         "Rampe de mise à l'eau"@fr ;
#     rdfs:subClassOf :SportsAndLeisurePlace .
#
# :LeftLuggage a owl:Class ;
#     rdfs:label "Left luggage"@en,
#         "Consigne à bagages"@fr ;
#     rdfs:subClassOf :ConvenientService .
#
# :LeisureChalet a owl:Class ;
#     rdfs:label "Leisure chalet"@en,
#         "Chalet résidentiel de loisirs"@fr ;
#     rdfs:subClassOf :AccommodationProduct .
#
# :LeisureComplex a owl:Class ;
#     rdfs:label "Leisure complex"@en,
#         "Complexe de loisirs (loisirs regroupés)"@fr ;
#     rdfs:subClassOf <http://schema.org/LocalBusiness>,
#         :SportsAndLeisurePlace .
#
# :LeisureSportActivityProvider a owl:Class ;
#     rdfs:label "Leisure and sport activity provider"@en,
#         "Prestataire d'activité sportive et de loisir"@fr ;
#     rdfs:subClassOf :ActivityProvider .
#
# :LevyOrDike a owl:Class ;
#     rdfs:label "Levy or dike"@en,
#         "Barrage, digue"@fr ;
#     rdfs:subClassOf :RemarkableBuilding .
#
# :Lighthouse a owl:Class ;
#     rdfs:label "Lighthouse"@en,
#         "Phare"@fr ;
#     rdfs:subClassOf :TechnicalHeritage .
#
# :LocalAnimation a owl:Class ;
#     rdfs:label "Local animation"@en,
#         "Animation locale"@fr ;
#     rdfs:subClassOf :SocialEvent .
#
# :LocalTouristOffice a owl:Class ;
#     rdfs:label "Local tourist office"@en,
#         "Office de tourisme"@fr ;
#     rdfs:subClassOf :TouristInformationCenter .
#
# :Lock a owl:Class ;
#     rdfs:label "Lock"@en,
#         "Ecluse"@fr ;
#     rdfs:subClassOf :RemarkableBuilding,
#         :Transport .
#
# :MTBRouteTheme a owl:Class ;
#     rdfs:label "MTB route name"@en,
#         "Itinéraire VTT"@fr ;
#     rdfs:subClassOf :RouteTheme .
#
# :Marina a owl:Class ;
#     rdfs:label "Marina"@en,
#         "Port de plaisance"@fr ;
#     rdfs:subClassOf :SportsAndLeisurePlace .
#
# :Market a owl:Class ;
#     rdfs:label "Market"@en,
#         "Marché"@fr ;
#     rdfs:subClassOf <http://schema.org/SaleEvent>,
#         :SaleEvent .
#
# :MegalithDolmenMenhir a owl:Class ;
#     rdfs:label "Megalith, dolmen, menhir"@en,
#         "Mégalithes, menhirs et dolmens"@fr ;
#     rdfs:subClassOf :ArcheologicalSite .
#
# :MilitaryCemetery a owl:Class ;
#     rdfs:label "Military cemetery and memorial"@en,
#         "Cimetière militaire et mémorial"@fr ;
#     rdfs:subClassOf :RemembranceSite .
#
# :Mill a owl:Class ;
#     rdfs:label "Mill"@en,
#         "Moulin"@fr ;
#     rdfs:subClassOf :TechnicalHeritage .
#
# :Mine a owl:Class ;
#     rdfs:label "Mine"@en,
#         "Mine"@fr ;
#     rdfs:subClassOf :TechnicalHeritage .
#
# :MiniGolf a owl:Class ;
#     rdfs:label "Mini golf"@en,
#         "Mini golf"@fr ;
#     rdfs:subClassOf :SportsAndLeisurePlace .
#
# :Monastery a owl:Class ;
#     rdfs:label "Monastery or priory"@en,
#         "Monastère, prieuré"@fr ;
#     rdfs:subClassOf :ReligiousSite .
#
# :MooringArea a owl:Class ;
#     rdfs:label "Mooring area"@en,
#         "Zone ou port de mouillage"@fr ;
#     rdfs:subClassOf :SportsAndLeisurePlace .
#
# :Mosque a owl:Class ;
#     rdfs:label "Mosque"@en,
#         "Mosquée"@fr ;
#     rdfs:subClassOf :ReligiousSite .
#
# :Mountain a owl:Class ;
#     rdfs:label "Mountain"@en,
#         "Montagne"@fr ;
#     rdfs:subClassOf :NaturalHeritage .
#
# :MountainResort a owl:Class ;
#     rdfs:label "Mountain resort"@en,
#         "Station de montagne"@fr ;
#     rdfs:subClassOf :CityHeritage .
#
# :MountainRestaurant a owl:Class ;
#     rdfs:label "Mountain restaurant"@en,
#         "Restaurant d'altitude / Restaurant d'alpage"@fr ;
#     rdfs:subClassOf :Restaurant .
#
# :MultiActivity a owl:Class ;
#     rdfs:label "Multi-activity"@en,
#         "Multiactivités"@fr ;
#     rdfs:subClassOf :Practice .
#
# :MultiPurposeRoomOrCommunityRoom a owl:Class ;
#     rdfs:label "Multi-purpose room, community room"@en,
#         "Salle polyvalente, salle des fêtes"@fr ;
#     rdfs:subClassOf :SportsAndLeisurePlace .
#
# :NaturalCuriosity a owl:Class ;
#     rdfs:label "Natural curiosity"@en,
#         "Curiosité naturelle"@fr ;
#     rdfs:subClassOf :NaturalHeritage .
#
# :NaturalPark a owl:Class ;
#     rdfs:label "Natural park"@en,
#         "Parc naturel"@fr ;
#     rdfs:subClassOf :NaturalHeritage .
#
# :NauticalCentre a owl:Class ;
#     rdfs:label "Nautical base / nautical centre"@en,
#         "Base nautique / centre nautique"@fr ;
#     rdfs:subClassOf :SportsAndLeisurePlace .
#
# :NightClub a owl:Class ;
#     rdfs:label "Night club"@en,
#         "Discothèque"@fr ;
#     rdfs:subClassOf <http://schema.org/NightClub>,
#         :SportsAndLeisurePlace .
#
# :NonHousingRealEstateRental a owl:Class ;
#     rdfs:label "Room rental"@en,
#         "Location de salle"@fr ;
#     rdfs:subClassOf [ a owl:Restriction ;
#             owl:allValuesFrom [ a owl:Class ;
#                     owl:unionOf ( :CommonFeatureSpecification :RoomFeatureSpecification ) ] ;
#             owl:onProperty :hasFeature ],
#         [ a owl:Restriction ;
#             owl:allValuesFrom [ a owl:Class ;
#                     owl:unionOf ( :CommonFeatureSpecification :RoomFeatureSpecification ) ] ;
#             owl:onProperty :hasFeature ],
#         [ a owl:Restriction ;
#             owl:allValuesFrom [ a owl:Class ;
#                     owl:unionOf ( :CommonFeatureSpecification :RoomFeatureSpecification ) ] ;
#             owl:onProperty :hasFeature ],
#         [ a owl:Restriction ;
#             owl:allValuesFrom [ a owl:Class ;
#                     owl:unionOf ( :CommonFeatureSpecification :RoomFeatureSpecification ) ] ;
#             owl:onProperty :hasFeature ],
#         [ a owl:Restriction ;
#             owl:allValuesFrom [ a owl:Class ;
#                     owl:unionOf ( :CommonFeatureSpecification :RoomFeatureSpecification ) ] ;
#             owl:onProperty :hasFeature ],
#         [ a owl:Restriction ;
#             owl:allValuesFrom [ a owl:Class ;
#                     owl:unionOf ( :CommonFeatureSpecification :RoomFeatureSpecification ) ] ;
#             owl:onProperty :hasFeature ],
#         [ a owl:Restriction ;
#             owl:allValuesFrom [ a owl:Class ;
#                     owl:unionOf ( :CommonFeatureSpecification :RoomFeatureSpecification ) ] ;
#             owl:onProperty :hasFeature ],
#         [ a owl:Restriction ;
#             owl:allValuesFrom [ a owl:Class ;
#                     owl:unionOf ( :CommonFeatureSpecification :RoomFeatureSpecification ) ] ;
#             owl:onProperty :hasFeature ],
#         :Rental .
#
# :OpenDay a owl:Class ;
#     rdfs:label "Open day"@en,
#         "Portes ouvertes"@fr ;
#     rdfs:subClassOf :SaleEvent .
#
# :Opera a owl:Class ;
#     rdfs:label "Opera"@en,
#         "Opéra"@fr ;
#     rdfs:subClassOf <http://schema.org/MusicEvent>,
#         :CulturalEvent .
#
# :Orchard a owl:Class ;
#     rdfs:label "Conservatory orchard"@en,
#         "Verger conservatoire"@fr ;
#     rdfs:subClassOf :TechnicalHeritage .
#
# :PDF a owl:Class ;
#     rdfs:label "PDF document"@en,
#         "Document PDF"@fr ;
#     rdfs:subClassOf <http://www.ebu.ch/metadata/ontologies/ebucore/ebucore#BusinessObject> .
#
# :Palace a owl:Class ;
#     rdfs:label "Palace"@en,
#         "Palais"@fr ;
#     rdfs:subClassOf :RemarkableBuilding .
#
# :Parade a owl:Class ;
#     rdfs:label "Parade"@en,
#         "Défilé Cortège Parade"@fr ;
#     rdfs:subClassOf :SocialEvent .
#
# :ParkAndGardenTheme a owl:Class ;
#     rdfs:label "Park and garden theme"@en,
#         "Thème de parc et jardin"@fr ;
#     rdfs:subClassOf :Theme .
#
# :Parking a owl:Class ;
#     rdfs:label "Parking"@en,
#         "Parking"@fr ;
#     rdfs:subClassOf :Transport .
#
# :Peak a owl:Class ;
#     rdfs:label "Peak"@en,
#         "Pic"@fr ;
#     rdfs:subClassOf :NaturalHeritage .
#
# :PicnicArea a owl:Class ;
#     rdfs:label "Picnic area"@en,
#         "Aire de pique-nique"@fr ;
#     rdfs:subClassOf :ConvenientService .
#
# :Pier a owl:Class ;
#     rdfs:label "Pier"@en,
#         "Jetée"@fr ;
#     rdfs:subClassOf :TechnicalHeritage .
#
# :PigeonLoft a owl:Class ;
#     rdfs:label "Pigeon loft"@en,
#         "Pigeonnier"@fr ;
#     rdfs:subClassOf :TechnicalHeritage .
#
# :PilgrimageAndProcession a owl:Class ;
#     rdfs:label "Pilgrimage and procession"@en,
#         "Pèlerinage et procession"@fr ;
#     rdfs:subClassOf :SocialEvent .
#
# :Plain a owl:Class ;
#     rdfs:label "Plain"@en,
#         "Plaine"@fr ;
#     rdfs:subClassOf :NaturalHeritage .
#
# :Plateau a owl:Class ;
#     rdfs:label "Plateau"@en,
#         "Plateau"@fr ;
#     rdfs:subClassOf :NaturalHeritage .
#
# :PlayArea a owl:Class ;
#     rdfs:label "Play area"@en,
#         "Aire de jeux"@fr ;
#     rdfs:subClassOf <http://schema.org/CivicStructure>,
#         :SportsAndLeisurePlace .
#
# :PointOfView a owl:Class ;
#     rdfs:label "PointOfView"@en,
#         "Point de vue"@fr ;
#     rdfs:subClassOf :NaturalHeritage .
#
# :Pond a owl:Class ;
#     rdfs:label "Pond"@en,
#         "Etang"@fr ;
#     rdfs:subClassOf :NaturalHeritage .
#
# :Producer a owl:Class ;
#     rdfs:label "Producer"@en,
#         "Producteur"@fr ;
#     rdfs:subClassOf :TastingProvider .
#
# :ProducersGroup a owl:Class ;
#     rdfs:label "Group of producers"@en,
#         "Groupement de producteurs"@fr ;
#     rdfs:subClassOf :TastingProvider .
#
# :ProfessionalTourGuide a owl:Class ;
#     rdfs:label "Professional tour guide"@en,
#         "Guide professionnel"@fr ;
#     rdfs:subClassOf :TouristInformationCenter .
#
# :PublicLavatories a owl:Class ;
#     rdfs:label "Public lavatories"@en,
#         "Toilettes publiques"@fr ;
#     rdfs:subClassOf :ConvenientService .
#
# :Quantity a owl:Class ;
#     rdfs:label "Quantity"@en,
#         "Quantité"@fr ;
#     rdfs:comment "A quantity describes the capacity a PointOfInterest provides for a given facility. e.g. capacity of swimming pool in a camping, capacity of people in a room, capacity of beds in a hotel, capacity of tables in a restaurant, ...."@en,
#         "Une quantité permet de décrire la capacité qu'un POI peut proposer pour un équipement donné. ex: capacité en nombre de piscines d'un camping, capacité en nombre de personnes d'une pièce, capacité en nombre de lits d'un hôtel, ...."@fr .
#
# :RVServiceArea a owl:Class ;
#     rdfs:label "RV service area"@en,
#         "Borne de service camping car"@fr ;
#     rdfs:subClassOf :ConvenientService .
#
# :Racetrack a owl:Class ;
#     rdfs:label "Racetrack"@en,
#         "Hippodrome"@fr ;
#     rdfs:subClassOf <http://schema.org/LocalBusiness>,
#         :SportsAndLeisurePlace .
#
# :RacingCircuit a owl:Class ;
#     rdfs:label "Racing circuit"@en,
#         "Circuit automobile ou moto"@fr ;
#     rdfs:subClassOf <http://schema.org/LocalBusiness>,
#         :SportsAndLeisurePlace .
#
# :Rally a owl:Class ;
#     rdfs:label "Rally"@en,
#         "Rallye"@fr ;
#     rdfs:subClassOf <http://schema.org/SportsEvent>,
#         :SportsEvent .
#
# :Rambling a owl:Class ;
#     rdfs:label "Hike and walk"@en,
#         "Randonnée, balade"@fr ;
#     rdfs:subClassOf <http://schema.org/SportsEvent>,
#         :SportsEvent .
#
# :Reading a owl:Class ;
#     rdfs:label "Reading"@en,
#         "Lecture"@fr ;
#     rdfs:subClassOf :CulturalEvent .
#
# :Recital a owl:Class ;
#     rdfs:label "Recital"@en,
#         "Récital"@fr ;
#     rdfs:subClassOf <http://schema.org/MusicEvent>,
#         :CulturalEvent .
#
# :RegionalTourismCommittee a owl:Class ;
#     rdfs:label "Regional tourism committee"@en,
#         "Comité régional du tourisme"@fr ;
#     rdfs:subClassOf :TouristInformationCenter .
#
# :ReligiousEvent a owl:Class ;
#     rdfs:label "Religious event"@en,
#         "Évènement religieux"@fr ;
#     rdfs:subClassOf :SocialEvent .
#
# :RemarkableHouse a owl:Class ;
#     rdfs:label "Remarkable house"@en,
#         "Maison remarquable"@fr ;
#     rdfs:subClassOf :RemarkableBuilding .
#
# :RentalPricingOffer a owl:Class ;
#     rdfs:label "Rental pricing Offer (without accommodation): bikes, kayak, meeting room"@en,
#         "Prestation tarifée de location (hors hébergement): vélo, salle de réunion"@fr ;
#     rdfs:subClassOf :PricingOffer .
#
# :River a owl:Class ;
#     rdfs:label "River"@en,
#         "Rivière ou fleuve"@fr ;
#     rdfs:subClassOf :NaturalHeritage .
#
# :RiverPort a owl:Class ;
#     rdfs:label "River port"@en,
#         "Halte et port fluvial"@fr ;
#     rdfs:subClassOf :Transport .
#
# :RoadTour a owl:Class ;
# ...
#         "Un système de classement décrit les valeurs possibles d'un classement donné. Un système de classement est généralement éligible à un type de POI donné. ex:  Guide Michelin, Plus beaux villages de France, ..."@fr .
#
# :Transport a owl:Class ;
#     rdfs:label "Transport"@en,
#         "Transport"@fr ;
#     rdfs:subClassOf [ a owl:Restriction ;
#             owl:allValuesFrom :CommonFeatureSpecification ;
#             owl:onProperty :hasFeature ],
#         [ a owl:Restriction ;
#             owl:allValuesFrom :CommonFeatureSpecification ;
#             owl:onProperty :hasFeature ],
#         [ a owl:Restriction ;
#             owl:allValuesFrom :CommonFeatureSpecification ;
#             owl:onProperty :hasFeature ],
#         [ a owl:Restriction ;
#             owl:allValuesFrom :CommonFeatureSpecification ;
#             owl:onProperty :hasFeature ],
#         [ a owl:Restriction ;
#             owl:allValuesFrom :CommonFeatureSpecification ;
#             owl:onProperty :hasFeature ],
#         [ a owl:Restriction ;
#             owl:allValuesFrom :CommonFeatureSpecification ;
#             owl:onProperty :hasFeature ],
#         [ a owl:Restriction ;
#             owl:allValuesFrom :CommonFeatureSpecification ;
#             owl:onProperty :hasFeature ],
#         [ a owl:Restriction ;
#             owl:allValuesFrom :CommonFeatureSpecification ;
#             owl:onProperty :hasFeature ],
#         :PlaceOfInterest .
#
# :PlaceOfInterest a owl:Class ;
#     rdfs:label "Place"@en,
#         "Lieu"@fr ;
#     rdfs:comment "A location that has a touristic interest."@en,
#         "Un lieu ayant un intérêt touristique."@fr ;
#     rdfs:subClassOf :PointOfInterest .
#
# :CulturalHeritageAmenity a owl:Class ;
#     rdfs:label "Cultural heritage facility and service"@en,
#         "Équipement et service de patrimoine culturel"@fr ;
#     rdfs:comment "Amenity provided by cultural heritage."@en,
#         "Équipement et service proposés par des patrimoines culturels."@fr ;
#     rdfs:subClassOf :Amenity .
#
# :InformativeAmenity a owl:Class ;
#     rdfs:label "Informative facilities and service"@en,
#         "Équipement et service d'information"@fr ;
#     rdfs:comment "An informative facility is a facility that provides information in a given language. e.g. flyers, catalog, map, video, ..."@en,
#         "Un équipement d'information est un équipement qui propose de la documentation dans un language donnée. ex : des prospectus, un catalogue, un plan, une borne vidéo, ..."@fr ;
#     rdfs:subClassOf :Amenity .
#
# :LabelRating a owl:Class ;
#     rdfs:label "Label"@en,
#         "Label"@fr ;
#     rdfs:comment "A label value"@en,
#         "Valeur labelisée."@fr ;
#     rdfs:subClassOf [ a owl:Restriction ;
#             owl:allValuesFrom :LabelReviewSystem ;
#             owl:onProperty :isRatingProvidedBy ],
#         [ a owl:Restriction ;
#             owl:allValuesFrom :LabelReviewSystem ;
#             owl:onProperty :isRatingProvidedBy ],
#         [ a owl:Restriction ;
#             owl:allValuesFrom :LabelReviewSystem ;
#             owl:onProperty :isRatingProvidedBy ],
#         [ a owl:Restriction ;
#             owl:allValuesFrom :LabelReviewSystem ;
#             owl:onProperty :isRatingProvidedBy ],
#         [ a owl:Restriction ;
#             owl:allValuesFrom :LabelReviewSystem ;
#             owl:onProperty :isRatingProvidedBy ],
#         [ a owl:Restriction ;
#             owl:allValuesFrom :LabelReviewSystem ;
#             owl:onProperty :isRatingProvidedBy ],
#         [ a owl:Restriction ;
#             owl:allValuesFrom :LabelReviewSystem ;
#             owl:onProperty :isRatingProvidedBy ],
#         [ a owl:Restriction ;
#             owl:allValuesFrom :LabelReviewSystem ;
#             owl:onProperty :isRatingProvidedBy ],
#         :Rating ;
#     owl:disjointWith :ScaleRating .
#
# :ReligiousSite a owl:Class ;
#     rdfs:label "Religious site"@en,
#         "Site religieux"@fr ;
#     rdfs:subClassOf :CulturalSite .
#
# :allowsRating a owl:ObjectProperty ;
#     rdfs:label "allows rating"@en,
#         "autorise"@fr ;
#     rdfs:comment "The rating this review system allows."@en,
#         "Les valeurs que ce système de classement autorise."@fr ;
#     rdfs:domain :ReviewSystem ;
#     rdfs:range :Rating ;
#     owl:inverseOf :isRatingProvidedBy .
#
# :hasReviewValue a owl:FunctionalProperty,
#         owl:ObjectProperty ;
#     rdfs:label "has value"@en,
#         "a pour valeur"@fr ;
#     rdfs:comment "The value of a review."@en,
#         "La valeur d'un classement."@fr ;
#     rdfs:domain :Review ;
#     rdfs:range :Rating ;
#     :hasPriority "5.5"^^xsd:float .
#
# :CulturalEvent a owl:Class ;
#     rdfs:label "Cultural event"@en,
#         "Évènement culturel"@fr ;
#     rdfs:subClassOf :EntertainmentAndEvent .
#
# :ScaleRating a owl:Class ;
#     rdfs:label "Rating"@en,
#         "Note"@fr ;
#     rdfs:comment "A rating value."@en,
#         "Valeur chiffrée (score)."@fr ;
#     rdfs:subClassOf [ a owl:Restriction ;
#             owl:allValuesFrom :ScaleReviewSystem ;
#             owl:onProperty :isRatingProvidedBy ],
#         [ a owl:Restriction ;
#             owl:allValuesFrom :ScaleReviewSystem ;
#             owl:onProperty :isRatingProvidedBy ],
#         [ a owl:Restriction ;
#             owl:allValuesFrom :ScaleReviewSystem ;
#             owl:onProperty :isRatingProvidedBy ],
#         [ a owl:Restriction ;
#             owl:allValuesFrom :ScaleReviewSystem ;
#             owl:onProperty :isRatingProvidedBy ],
#         [ a owl:Restriction ;
#             owl:allValuesFrom :ScaleReviewSystem ;
#             owl:onProperty :isRatingProvidedBy ],
#         [ a owl:Restriction ;
#             owl:allValuesFrom :ScaleReviewSystem ;
#             owl:onProperty :isRatingProvidedBy ],
#         [ a owl:Restriction ;
#             owl:allValuesFrom :ScaleReviewSystem ;
#             owl:onProperty :isRatingProvidedBy ],
#         [ a owl:Restriction ;
#             owl:allValuesFrom :ScaleReviewSystem ;
#             owl:onProperty :isRatingProvidedBy ],
#         <http://schema.org/Rating>,
#         :Rating .
#
# :isRatingProvidedBy a owl:ObjectProperty ;
#     rdfs:label "is provided by"@en,
#         "est une valeur de"@fr ;
#     rdfs:comment "The review system this rating is provided by."@en,
#         "Le système de classement qui propose cette valeur."@fr ;
#     rdfs:domain :Rating ;
#     rdfs:range :ReviewSystem .
#
# :TastingProvider a owl:Class ;
#     rdfs:label "Tasting provider"@en,
#         "Fournisseur de dégustation"@fr ;
#     rdfs:comment "A provider that provides tasting."@en,
#         "Un prestataire qui propose des dégustations."@fr ;
#     rdfs:subClassOf <http://schema.org/LocalBusiness>,
#         :PlaceOfInterest .
#
# <http://schema.org/LocalBusiness> a owl:Class .
#
# :AccommodationProduct a owl:Class ;
#     rdfs:label "Accommodation product"@en,
#         "Produit d'hébergement"@fr ;
#     rdfs:subClassOf :Product .
#
# :LimitedPeriod a owl:Class ;
#     rdfs:label "Limited period"@en,
#         "Période limitée"@fr ;
#     rdfs:comment "A period that has a defined start and end."@en,
#         "Une période qui est finie dans le temps (a un début et une fin établie)."@fr ;
#     rdfs:subClassOf :Period ;
#     owl:disjointWith :RecurrentPeriod .
#
# :Place a owl:Class ;
#     rdfs:label "Place"@en,
#         "Lieu"@fr .
#
# :RecurrentPeriod a owl:Class ;
#     rdfs:label "Recurrent period"@en,
#         "Période récurrente"@fr ;
#     rdfs:comment "Define intervals that occurs periodically. e.g. every Monday from 10am to 12am."@en,
#         "Défini des intervalles qui se produisent périodiquement. ex: tous les lundis de 10h à 12h."@fr ;
#     rdfs:subClassOf :Period .
#
# :NaturalHeritage a owl:Class ;
#     rdfs:label "Natural heritage"@en,
#         "Site naturel"@fr ;
#     rdfs:subClassOf [ a owl:Restriction ;
#             owl:allValuesFrom [ a owl:Class ;
#                     owl:unionOf ( :CommonFeatureSpecification :NaturalHeritageFeatureSpecification ) ] ;
#             owl:onProperty :hasFeature ],
#         [ a owl:Restriction ;
#             owl:allValuesFrom [ a owl:Class ;
#                     owl:unionOf ( :CommonFeatureSpecification :NaturalHeritageFeatureSpecification ) ] ;
#             owl:onProperty :hasFeature ],
#         [ a owl:Restriction ;
#             owl:allValuesFrom [ a owl:Class ;
#                     owl:unionOf ( :CommonFeatureSpecification :NaturalHeritageFeatureSpecification ) ] ;
#             owl:onProperty :hasFeature ],
#         [ a owl:Restriction ;
#             owl:allValuesFrom [ a owl:Class ;
#                     owl:unionOf ( :CommonFeatureSpecification :NaturalHeritageFeatureSpecification ) ] ;
#             owl:onProperty :hasFeature ],
#         [ a owl:Restriction ;
#             owl:allValuesFrom [ a owl:Class ;
#                     owl:unionOf ( :CommonFeatureSpecification :NaturalHeritageFeatureSpecification ) ] ;
#             owl:onProperty :hasFeature ],
#         [ a owl:Restriction ;
#             owl:allValuesFrom [ a owl:Class ;
#                     owl:unionOf ( :CommonFeatureSpecification :NaturalHeritageFeatureSpecification ) ] ;
#             owl:onProperty :hasFeature ],
#         [ a owl:Restriction ;
#             owl:allValuesFrom [ a owl:Class ;
#                     owl:unionOf ( :CommonFeatureSpecification :NaturalHeritageFeatureSpecification ) ] ;
#             owl:onProperty :hasFeature ],
#         [ a owl:Restriction ;
#             owl:allValuesFrom [ a owl:Class ;
#                     owl:unionOf ( :CommonFeatureSpecification :NaturalHeritageFeatureSpecification ) ] ;
#             owl:onProperty :hasFeature ],
#         :PlaceOfInterest .
#
# :Tour a owl:Class ;
#     rdfs:label "Route"@en,
#         "Itinéraire touristique"@fr ;
#     rdfs:comment "A tourist route is a Product that provides a succession of paths."@en,
#         "Un itinéraire touristique est un produit qui propose un itinéraire composé de parcours."@fr ;
#     rdfs:subClassOf [ a owl:Restriction ;
#             owl:allValuesFrom :CommonFeatureSpecification ;
#             owl:onProperty :hasFeature ],
#         [ a owl:Restriction ;
#             owl:allValuesFrom :CommonFeatureSpecification ;
#             owl:onProperty :hasFeature ],
#         [ a owl:Restriction ;
#             owl:allValuesFrom :CommonFeatureSpecification ;
#             owl:onProperty :hasFeature ],
#         [ a owl:Restriction ;
#             owl:allValuesFrom :CommonFeatureSpecification ;
#             owl:onProperty :hasFeature ],
#         [ a owl:Restriction ;
#             owl:allValuesFrom :CommonFeatureSpecification ;
#             owl:onProperty :hasFeature ],
#         [ a owl:Restriction ;
#             owl:allValuesFrom :CommonFeatureSpecification ;
#             owl:onProperty :hasFeature ],
#         [ a owl:Restriction ;
#             owl:allValuesFrom :CommonFeatureSpecification ;
#             owl:onProperty :hasFeature ],
#         [ a owl:Restriction ;
#             owl:allValuesFrom :CommonFeatureSpecification ;
#             owl:onProperty :hasFeature ],
#         <http://purl.org/ontology/olo/core#OrderedList>,
#         :PointOfInterest .
#
# :RoomFeatureSpecification a owl:Class ;
#     rdfs:label "Room feature specification"@en,
#         "Spécification d'équipement de pièce"@fr ;
#     rdfs:subClassOf [ a owl:Restriction ;
#             owl:allValuesFrom :RoomAmenity ;
#             owl:onProperty :features ],
#         [ a owl:Restriction ;
#             owl:allValuesFrom :RoomAmenity ;
#             owl:onProperty :features ],
#         [ a owl:Restriction ;
#             owl:allValuesFrom :RoomAmenity ;
#             owl:onProperty :features ],
#         [ a owl:Restriction ;
#             owl:allValuesFrom :RoomAmenity ;
#             owl:onProperty :features ],
#         [ a owl:Restriction ;
#             owl:allValuesFrom :RoomAmenity ;
#             owl:onProperty :features ],
#         [ a owl:Restriction ;
#             owl:allValuesFrom :RoomAmenity ;
#             owl:onProperty :features ],
#         [ a owl:Restriction ;
#             owl:allValuesFrom :RoomAmenity ;
#             owl:onProperty :features ],
#         [ a owl:Restriction ;
#             owl:allValuesFrom :RoomAmenity ;
#             owl:onProperty :features ],
#         <http://schema.org/LocationFeatureSpecification>,
#         :FeatureSpecification .
#
# :SportsAndLeisurePlace a owl:Class ;
#     rdfs:label "Sports and leisure place"@en,
#         "Site sportif, récréatif et de loisirs"@fr ;
#     rdfs:subClassOf [ a owl:Restriction ;
#             owl:allValuesFrom :CommonFeatureSpecification ;
#             owl:onProperty :hasFeature ],
#         [ a owl:Restriction ;
#             owl:allValuesFrom :CommonFeatureSpecification ;
#             owl:onProperty :hasFeature ],
#         [ a owl:Restriction ;
#             owl:allValuesFrom :CommonFeatureSpecification ;
#             owl:onProperty :hasFeature ],
#         [ a owl:Restriction ;
#             owl:allValuesFrom :CommonFeatureSpecification ;
#             owl:onProperty :hasFeature ],
#         [ a owl:Restriction ;
#             owl:allValuesFrom :CommonFeatureSpecification ;
#             owl:onProperty :hasFeature ],
#         [ a owl:Restriction ;
#             owl:allValuesFrom :CommonFeatureSpecification ;
#             owl:onProperty :hasFeature ],
#         [ a owl:Restriction ;
#             owl:allValuesFrom :CommonFeatureSpecification ;
#             owl:onProperty :hasFeature ],
#         [ a owl:Restriction ;
#             owl:allValuesFrom :CommonFeatureSpecification ;
#             owl:onProperty :hasFeature ],
#         :PlaceOfInterest .
#
# :features a owl:ObjectProperty ;
#     rdfs:label "features"@en,
#         "associe"@fr ;
#     rdfs:comment "The facility or service this specification is associated with"@en,
#         "L'équipement ou service auquel cette spécification se rapporte"@fr ;
#     rdfs:domain :FeatureSpecification ;
#     rdfs:range :Amenity ;
#     :hasPriority "5.5"^^xsd:float .
#
# :PointOfInterest a owl:Class ;
#     rdfs:label "Point of interest"@en,
#         "Point d'intérêt"@fr ;
#     rdfs:comment "Any touristic item that deserves to be described and exposed. A POI (Point of Interest) is a touristic item that is owned by an Agent and that can be consumed via Prestations. (Services) e.g. A Restaurant, a Hotel, a Practice, a Patrimonial item."@en,
#         "Tout objet touristique qui mérite d'être décrit et valorisé. Un POI (Point of Interest) est un élément touristique qui est géré par un Agent et qui peut être consommé via des Produits et Services. ex : Un Restaurant, un Hôtel, une Pratique, un Objet patrimonial"@fr .
#
# :TourPath a owl:Class ;
#     rdfs:label "Route stage"@en,
#         "Etape de l'itinéraire"@fr ;
#     rdfs:comment "All the information about a route stage."@en,
#         "Le détail d'une étape d'itinéraire."@fr .
#
# :CommonFeatureSpecification a owl:Class ;
#     rdfs:label "Common feature specification"@en,
#         "Spécification d'équipement commun"@fr ;
#     rdfs:subClassOf [ a owl:Restriction ;
#             owl:allValuesFrom :CommonAmenity ;
#             owl:onProperty :features ],
#         [ a owl:Restriction ;
#             owl:allValuesFrom :CommonAmenity ;
#             owl:onProperty :features ],
#         [ a owl:Restriction ;
#             owl:allValuesFrom :CommonAmenity ;
#             owl:onProperty :features ],
#         [ a owl:Restriction ;
#             owl:allValuesFrom :CommonAmenity ;
#             owl:onProperty :features ],
#         [ a owl:Restriction ;
#             owl:allValuesFrom :CommonAmenity ;
#             owl:onProperty :features ],
#         [ a owl:Restriction ;
#             owl:allValuesFrom :CommonAmenity ;
#             owl:onProperty :features ],
#         [ a owl:Restriction ;
#             owl:allValuesFrom :CommonAmenity ;
#             owl:onProperty :features ],
#         [ a owl:Restriction ;
#             owl:allValuesFrom :CommonAmenity ;
#             owl:onProperty :features ],
#         :FeatureSpecification .
#
# :hasFeature a owl:ObjectProperty ;
#     rdfs:label "provides facilities and services"@en,
#         "propose comme équipement et service"@fr ;
#     rdfs:comment "The features information (amenities, services infos) this POI provides."@en,
#         "La spécification des équipements et services que propose ce POI."@fr ;
#     rdfs:domain :PointOfInterest ;
#     rdfs:range :FeatureSpecification ;
#     :hasPriority "5.0"^^xsd:float .

# %%
Uris = [
            "https://www.datatourisme.gouv.fr/ontology/core#Museum",
            "https://www.datatourisme.gouv.fr/ontology/core#InterpretationCentre",
            "https://www.datatourisme.gouv.fr/ontology/core#Library",
            "https://www.datatourisme.gouv.fr/ontology/core#ParkAndGarden",
            "https://www.datatourisme.gouv.fr/ontology/core#ArcheologicalSite",
            "https://www.datatourisme.gouv.fr/ontology/core#ReligiousSite",
            "https://www.datatourisme.gouv.fr/ontology/core#RemarkableBuilding",
            "https://www.datatourisme.gouv.fr/ontology/core#CityHeritage",
            "https://www.datatourisme.gouv.fr/ontology/core#DefenceSite",
            "https://www.datatourisme.gouv.fr/ontology/core#RemembranceSite",
            "https://www.datatourisme.gouv.fr/ontology/core#TechnicalHeritage",
            "https://www.datatourisme.gouv.fr/ontology/core#FoodEstablishment",
            "https://www.datatourisme.gouv.fr/ontology/core#NaturalHeritage",
            "https://www.datatourisme.gouv.fr/ontology/core#SportsAndLeisurePlace",
            "https://www.datatourisme.gouv.fr/ontology/core#Store"]

# %%
for subj, pred, obj in g:
    
    if subj in 
    URIRef("http://example.org/people/Bob")
    print(type(subj))
    print('->subj ',subj)
    print('->pred ',pred)
    print('->obj ',obj)
    print('\n')
# Out:
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#pending
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  En cours de classement
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#hasLocomotionWay
# ->pred  http://www.w3.org/2000/01/rdf-schema#range
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#SportsTheme
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#ProducersGroup
# ->pred  http://www.w3.org/2000/01/rdf-schema#subClassOf
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#TastingProvider
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#hasManagementContact
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  a pour contact à la direction
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#SpatialEnvironmentTheme
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Thème d'environnement de POI
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#DownhillSkiResort
# ->pred  http://www.w3.org/2000/01/rdf-schema#subClassOf
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#SportsAndLeisurePlace
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#Hammam
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Hammam
#
#
# <class 'rdflib.term.BNode'>
# ->subj  n30116622feda4b918a38de49f3b91eb2b109
# ->pred  http://www.w3.org/2002/07/owl#allValuesFrom
# ->obj  n30116622feda4b918a38de49f3b91eb2b110
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#Arena
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Arena
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#Museum
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#Class
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#endDate
# ->pred  http://www.w3.org/2000/01/rdf-schema#domain
# ->obj  n30116622feda4b918a38de49f3b91eb2b41
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#insee
# ->pred  http://www.w3.org/2000/01/rdf-schema#comment
# ->obj  Code INSEE de la division administrative
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#CamperVanArea
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#Class
#
#
# <class 'rdflib.term.BNode'>
# ->subj  n30116622feda4b918a38de49f3b91eb2b64
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#rest
# ->obj  n30116622feda4b918a38de49f3b91eb2b65
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#Culture
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Culture
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#FoodProduct
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Food product
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#FrontonBelotaCourt
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Fronton, mur de frappe
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#hasPart
# ->pred  http://www.w3.org/2000/01/rdf-schema#subPropertyOf
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#isReferencedBy
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#ExecutiveBoardMeeting
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Bureau éxécutif
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core
# ->pred  http://purl.org/dc/terms/contributor
# ->obj  Ricochets - https://www.ricochets.net/
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#HotelTrade
# ->pred  http://www.w3.org/2000/01/rdf-schema#subClassOf
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#Accommodation
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#ProfessionalTourGuide
# ->pred  http://www.w3.org/2000/01/rdf-schema#subClassOf
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#TouristInformationCenter
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#IceCreamShop
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Ice cream shop
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  http://schema.org/Winery
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#Class
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#isLocatedAt
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#ObjectProperty
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#MedicalPlace
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Medical place
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#isOwnedBy
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  is owned by
#
#
# <class 'rdflib.term.BNode'>
# ->subj  n30116622feda4b918a38de49f3b91eb2b61
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#rest
# ->obj  n30116622feda4b918a38de49f3b91eb2b62
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#Apartment
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Apartment
#
#
# <class 'rdflib.term.BNode'>
# ->subj  n30116622feda4b918a38de49f3b91eb2b84
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#Restriction
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#GourmetRestaurant
# ->pred  http://www.w3.org/2000/01/rdf-schema#subClassOf
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#Restaurant
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#openingDetails
# ->pred  http://www.w3.org/2000/01/rdf-schema#range
# ->obj  http://www.w3.org/1999/02/22-rdf-syntax-ns#langString
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#Review
# ->pred  http://www.w3.org/2000/01/rdf-schema#comment
# ->obj  Un classement permet d'associer une valeur de classement à un POI. Ex: 3 étoiles, 4 Epis, "Plus beau village de France", ...
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#Commanderie
# ->pred  http://www.w3.org/2000/01/rdf-schema#subClassOf
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#ReligiousSite
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#suggests
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#ObjectProperty
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#hasPublished
# ->pred  http://www.w3.org/2000/01/rdf-schema#range
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#PointOfInterest
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#IncomingTravelAgency
# ->pred  http://www.w3.org/2000/01/rdf-schema#subClassOf
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#TouristInformationCenter
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#hasBeenCreatedBy
# ->pred  http://www.w3.org/2000/01/rdf-schema#comment
# ->obj  The agent who has created the POI in the system.
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#TourismCentre
# ->pred  http://www.w3.org/2000/01/rdf-schema#subClassOf
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#TouristInformationCenter
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#duration
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#FunctionalProperty
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#ExecutiveBoardMeeting
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#Class
#
#
# <class 'rdflib.term.BNode'>
# ->subj  n30116622feda4b918a38de49f3b91eb2b23
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#first
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#LocalProductsShop
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#Wetland
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Zone humide
#
#
# <class 'rdflib.term.BNode'>
# ->subj  n30116622feda4b918a38de49f3b91eb2b9
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#first
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#TourPath
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#HolidayCentre
# ->pred  http://www.w3.org/2000/01/rdf-schema#subClassOf
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#CollectiveAccommodation
#
#
# <class 'rdflib.term.BNode'>
# ->subj  n30116622feda4b918a38de49f3b91eb2b114
# ->pred  http://www.w3.org/2002/07/owl#onProperty
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#hasFeature
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#hasInformativeContact
# ->pred  http://www.w3.org/2000/01/rdf-schema#comment
# ->obj  L'agent à contacter pour affaires informatives relatives à ce POI.
#
#
# <class 'rdflib.term.BNode'>
# ->subj  n30116622feda4b918a38de49f3b91eb2b77
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#rest
# ->obj  http://www.w3.org/1999/02/22-rdf-syntax-ns#nil
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#CycleRouteTheme
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Itinéraire vélo route
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#MegalithDolmenMenhir
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Mégalithes, menhirs et dolmens
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#isDedicatedTo
# ->pred  http://www.w3.org/2000/01/rdf-schema#comment
# ->obj  The audience the item is dedicated to.
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#Farmer
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Éleveur
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#rightsEndDate
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Rights ending date
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#KidsClub
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Club enfants
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#YachtClub
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#Class
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#HouseBoat
# ->pred  http://www.w3.org/2000/01/rdf-schema#subClassOf
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#AccommodationProduct
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  http://schema.org/Museum
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#Class
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#CateringAmenity
# ->pred  http://www.w3.org/2000/01/rdf-schema#comment
# ->obj  Équipement lié à la restauration. Ex: couverts
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#Parade
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#Class
#
#
# <class 'rdflib.term.BNode'>
# ->subj  n30116622feda4b918a38de49f3b91eb2b132
# ->pred  http://www.w3.org/2002/07/owl#allValuesFrom
# ->obj  n30116622feda4b918a38de49f3b91eb2b133
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#AccompaniedPractice
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Accompanied practice
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#CommonAmenity
# ->pred  http://www.w3.org/2000/01/rdf-schema#subClassOf
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#Amenity
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#Abbey
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#Class
#
#
# <class 'rdflib.term.BNode'>
# ->subj  n30116622feda4b918a38de49f3b91eb2b59
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#rest
# ->obj  http://www.w3.org/1999/02/22-rdf-syntax-ns#nil
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#Glacier
# ->pred  http://www.w3.org/2000/01/rdf-schema#subClassOf
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#NaturalHeritage
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#providesFoodProduct
# ->pred  http://www.w3.org/2000/01/rdf-schema#range
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#FoodProduct
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#IceSkatingRink
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Patinoire
#
#
# <class 'rdflib.term.BNode'>
# ->subj  n30116622feda4b918a38de49f3b91eb2b60
# ->pred  http://www.w3.org/2002/07/owl#unionOf
# ->obj  n30116622feda4b918a38de49f3b91eb2b61
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#SportsTheme
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#Class
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#LeisureChalet
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Chalet résidentiel de loisirs
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  http://schema.org/Hotel
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#Class
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#hasPricingOffer
# ->pred  http://www.w3.org/2000/01/rdf-schema#comment
# ->obj  Prestation sur laquelle s'applique la spécification tarifaire.
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  http://schema.org/Library
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#Class
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#City
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  City
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#Theme
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Theme
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#CraftsmanShop
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Artisan d'art
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#FitnessCenter
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Centre de remise en forme - fitness
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#creationDate
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Date de création
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#Cirque
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Cirque
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#Arena
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#Class
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#Canyon
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Canyon
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#hasLayout
# ->pred  http://www.w3.org/2000/01/rdf-schema#comment
# ->obj  The layout of the room associated to this specification.
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#noSmoking
# ->pred  https://www.datatourisme.gouv.fr/ontology/core#hasPriority
# ->obj  4.0
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#MegalithDolmenMenhir
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#Class
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#PeopleAudience
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  People audience
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#Monastery
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Monastère, prieuré
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#suggests
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  recommande
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#startTime
# ->pred  http://www.w3.org/2000/01/rdf-schema#domain
# ->obj  n30116622feda4b918a38de49f3b91eb2b72
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#TypeOfBed
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Type of bed
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#hasAudience
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  has audience
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#HealthTheme
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#Class
#
#
# <class 'rdflib.term.BNode'>
# ->subj  n30116622feda4b918a38de49f3b91eb2b58
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#rest
# ->obj  n30116622feda4b918a38de49f3b91eb2b59
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#TennisComplex
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#Class
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#Chapel
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Chapelle
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#LabelReviewSystem
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Système de classement par label
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#HealthcarePlace
# ->pred  http://www.w3.org/2000/01/rdf-schema#comment
# ->obj  A place where someone can receive healthcare (a hospital, a clinic, ...)
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#ClubOrHolidayVillage
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#Class
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#EquipmentRentalShop
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Equipment rental shop
#
#
# <class 'rdflib.term.BNode'>
# ->subj  n30116622feda4b918a38de49f3b91eb2b1
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#Class
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#PDF
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#Class
#
#
# <class 'rdflib.term.BNode'>
# ->subj  n30116622feda4b918a38de49f3b91eb2b105
# ->pred  http://www.w3.org/2002/07/owl#allValuesFrom
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#LabelReviewSystem
#
#
# <class 'rdflib.term.BNode'>
# ->subj  n30116622feda4b918a38de49f3b91eb2b4
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#Class
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#ArcheologicalSite
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Archeological site
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#LabelReviewSystem
# ->pred  http://www.w3.org/2002/07/owl#disjointWith
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#ScaleReviewSystem
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#ScaleReviewSystem
# ->pred  http://www.w3.org/2000/01/rdf-schema#subClassOf
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#ReviewSystem
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#lastUpdate
# ->pred  https://www.datatourisme.gouv.fr/ontology/core#hasPriority
# ->obj  8.0
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#providesFoodProduct
# ->pred  http://www.w3.org/2000/01/rdf-schema#domain
# ->obj  n30116622feda4b918a38de49f3b91eb2b22
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#Cinematheque
# ->pred  http://www.w3.org/2000/01/rdf-schema#subClassOf
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#SportsAndLeisurePlace
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#ZooAnimalPark
# ->pred  http://www.w3.org/2000/01/rdf-schema#subClassOf
# ->obj  http://schema.org/LocalBusiness
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#isCompliantWith
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  est compatible avec
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#COVID19OpeningPeriodsConfirmed
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Périodes d'ouvertures confirmées – déconfinement COVID19
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  http://www.ebu.ch/metadata/ontologies/ebucore/ebucore#EditorialObject
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#Class
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#CuisineCategory
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Cuisine category
#
#
# <class 'rdflib.term.BNode'>
# ->subj  n30116622feda4b918a38de49f3b91eb2b46
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#first
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#RecurrentPeriod
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#hasTheme
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#ObjectProperty
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#Cooperative
# ->pred  http://www.w3.org/2000/01/rdf-schema#subClassOf
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#TastingProvider
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#CulturalTheme
# ->pred  http://www.w3.org/2000/01/rdf-schema#subClassOf
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#Theme
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#CoveredMarket
# ->pred  http://www.w3.org/2000/01/rdf-schema#subClassOf
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#TechnicalHeritage
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#ExecutiveBoardMeeting
# ->pred  http://www.w3.org/2000/01/rdf-schema#subClassOf
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#BusinessEvent
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#FortifiedCastle
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#Class
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#duration
# ->pred  http://www.w3.org/2000/01/rdf-schema#domain
# ->obj  n30116622feda4b918a38de49f3b91eb2b38
#
#
# <class 'rdflib.term.BNode'>
# ->subj  n30116622feda4b918a38de49f3b91eb2b86
# ->pred  http://www.w3.org/2002/07/owl#onProperty
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#features
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#Mill
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#Class
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#Theme
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#Class
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#rightsStartDate
# ->pred  http://www.w3.org/2000/01/rdf-schema#comment
# ->obj  La date à laquelle les droits commencent à s'appliquer sur ce média (aaaa-mm-jj).
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#PlaceOfInterest
# ->pred  http://www.w3.org/2000/01/rdf-schema#subClassOf
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#PointOfInterest
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#TrainStation
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Gare ferroviaire
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#SummerToboggan
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Piste de luge d'été
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#requiredMaxPersonCount
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#FunctionalProperty
#
#
# <class 'rdflib.term.BNode'>
# ->subj  n30116622feda4b918a38de49f3b91eb2b75
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#Class
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#Concert
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#Class
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#BoatRestaurant
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Bateau-restaurant
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#NaturalHeritage
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Site naturel
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#Hotel
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Hôtel
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#Landes
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#Class
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#endTime
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Heure de fin
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#ParkAndGarden
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Park and garden
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#Bocage
# ->pred  http://www.w3.org/2000/01/rdf-schema#subClassOf
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#NaturalHeritage
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#isPartOfCountry
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  fait partie du pays
#
#
# <class 'rdflib.term.BNode'>
# ->subj  n30116622feda4b918a38de49f3b91eb2b93
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#Restriction
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#FoodEstablishmentTheme
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Food establishment theme
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#hasEligibleAudience
# ->pred  http://www.w3.org/2000/01/rdf-schema#comment
# ->obj  The people audience this pricing applies on. e.g. Teenagers, Adults, ...
#
#
# <class 'rdflib.term.BNode'>
# ->subj  n30116622feda4b918a38de49f3b91eb2b31
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#rest
# ->obj  http://www.w3.org/1999/02/22-rdf-syntax-ns#nil
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#CulturalEvent
# ->pred  http://www.w3.org/2000/01/rdf-schema#subClassOf
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#EntertainmentAndEvent
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#bestRating
# ->pred  http://www.w3.org/2000/01/rdf-schema#comment
# ->obj  Le score le plus haut que le système de classement propose.
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#NightClub
# ->pred  http://www.w3.org/2000/01/rdf-schema#subClassOf
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#SportsAndLeisurePlace
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#Audience
# ->pred  http://www.w3.org/2000/01/rdf-schema#comment
# ->obj  Intended audience for an item. Usually a group of Agents related to a common criteria. e.g. Children, Teenagers, Scholars, ...
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#CulturalActivityProvider
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Cultural activity provider
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#Peak
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Peak
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#Volcano
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Volcano
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#IncomingTravelAgency
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Incoming travel agency
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#Citadel
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Citadel
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#Rental
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Location
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  http://schema.org/LocationFeatureSpecification
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#Class
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#CarOrBikeWash
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Station de lavage
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#Period
# ->pred  http://www.w3.org/2000/01/rdf-schema#comment
# ->obj  Une période est soit un intervalle de temps défini par une date et heure de début et de fin (ex: du 14/07/2016 à 00h au 14/08/2016 à 12h), soit une récurrence d'intervalle (ex: tous les lundis et mercredi de 10h à 12h). Attention, Period n'est pas similaire à schema:Event, car au sens schema.org, un Event est une manifestation qui peut proposer des schema:Offers. Ici, Period n'est qu'un intervalle de temps sans autre portée sémantique.
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#ReligiousSite
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#Class
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#hasEligibleAudience
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  est éligible pour l'audience
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#allowedPersons
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Capacity (number of persons)
#
#
# <class 'rdflib.term.BNode'>
# ->subj  n30116622feda4b918a38de49f3b91eb2b110
# ->pred  http://www.w3.org/2002/07/owl#unionOf
# ->obj  n30116622feda4b918a38de49f3b91eb2b111
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#Waterfall
# ->pred  http://www.w3.org/2000/01/rdf-schema#subClassOf
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#NaturalHeritage
#
#
# <class 'rdflib.term.BNode'>
# ->subj  n30116622feda4b918a38de49f3b91eb2b8
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#first
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#PointOfInterest
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#BoulesPitch
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Boules pitch
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#Organisation
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Organisation
#
#
# <class 'rdflib.term.BNode'>
# ->subj  n30116622feda4b918a38de49f3b91eb2b123
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#Restriction
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#hasAudience
# ->pred  http://www.w3.org/2000/01/rdf-schema#comment
# ->obj  L'audience ciblée par cet objet.
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#LabelReview
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#Class
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#Cathedral
# ->pred  http://www.w3.org/2000/01/rdf-schema#subClassOf
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#ReligiousSite
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#NaturalCuriosity
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Natural curiosity
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#isRatingProvidedBy
# ->pred  http://www.w3.org/2000/01/rdf-schema#domain
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#Rating
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#minAltitude
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#FunctionalProperty
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#LocalProductsShop
# ->pred  http://www.w3.org/2000/01/rdf-schema#subClassOf
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#Store
#
#
# <class 'rdflib.term.BNode'>
# ->subj  n30116622feda4b918a38de49f3b91eb2b118
# ->pred  http://www.w3.org/2002/07/owl#onProperty
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#hasFeature
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#ConeNeck
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#Class
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#Icefall
# ->pred  http://www.w3.org/2000/01/rdf-schema#subClassOf
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#NaturalHeritage
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#Mountain
# ->pred  http://www.w3.org/2000/01/rdf-schema#subClassOf
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#NaturalHeritage
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#HorseTour
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#Class
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#WaterSource
# ->pred  http://www.w3.org/2000/01/rdf-schema#subClassOf
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#ConvenientService
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#seatCount
# ->pred  http://www.w3.org/2000/01/rdf-schema#comment
# ->obj  Le nombre de places assises sur la surface concernée
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#hasLayout
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#ObjectProperty
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#hasPricingSeason
# ->pred  http://www.w3.org/2000/01/rdf-schema#comment
# ->obj  Season on which applies the price specification.
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#Farm
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Ferme
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#hasPart
# ->pred  http://www.w3.org/2000/01/rdf-schema#comment
# ->obj  Un sous-produit de ce produit (par exemple si le produit est un composant de celui-ci). Ex: un court de golf dans un camping.
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#Competition
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#Class
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#EquipmentRental
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#Class
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#ClubOrHolidayVillage
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Club et village vacances
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#requiredMinPersonCount
# ->pred  http://www.w3.org/2000/01/rdf-schema#domain
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#PeopleAudience
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#LimitedPeriod
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#Class
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#Gorge
# ->pred  http://www.w3.org/2000/01/rdf-schema#subClassOf
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#NaturalHeritage
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#CarOrBikeWash
# ->pred  http://www.w3.org/2000/01/rdf-schema#subClassOf
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#ConvenientService
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#BistroOrWineBar
# ->pred  http://www.w3.org/2000/01/rdf-schema#subClassOf
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#FoodEstablishment
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#Landes
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Landes
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#Temple
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Temple
#
#
# <class 'rdflib.term.BNode'>
# ->subj  n30116622feda4b918a38de49f3b91eb2b114
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#Restriction
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#Seaport
# ->pred  http://www.w3.org/2000/01/rdf-schema#subClassOf
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#Transport
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#Audience
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Audience
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#petsAllowed
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#FunctionalProperty
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#Synagogue
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Synagogue
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#Monastery
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#Class
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#PlayArea
# ->pred  http://www.w3.org/2000/01/rdf-schema#subClassOf
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#SportsAndLeisurePlace
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#Hut
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Hut
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#KML
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Document KML
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#GeographicReach
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Geographic reach
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#Cinematheque
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Cinémathèque
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#NaturalHeritageFeatureSpecification
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Natural heritage feature specification
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#Organisation
# ->pred  http://www.w3.org/2000/01/rdf-schema#subClassOf
# ->obj  http://schema.org/Organization
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#isEquippedWith
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#ObjectProperty
#
#
# <class 'rdflib.term.BNode'>
# ->subj  n30116622feda4b918a38de49f3b91eb2b94
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#Restriction
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#RegionalTourismCommittee
# ->pred  http://www.w3.org/2000/01/rdf-schema#subClassOf
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#TouristInformationCenter
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#providesCuisineOfType
# ->pred  http://www.w3.org/2000/01/rdf-schema#subPropertyOf
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#hasTheme
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#AntiqueAndSecondhandGoodDealer
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Antique and second-hand goods dealer
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#LevyOrDike
# ->pred  http://www.w3.org/2000/01/rdf-schema#subClassOf
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#RemarkableBuilding
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#startTime
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#DatatypeProperty
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#RoomLayout
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Room layout
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#LabelRating
# ->pred  http://www.w3.org/2002/07/owl#disjointWith
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#ScaleRating
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#Palace
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#Class
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#hasRepresentation
# ->pred  http://www.w3.org/2000/01/rdf-schema#comment
# ->obj  Une représentation est un Media qui est lié à un POI. ex : une photo d'un POI, un document PDF promotionnel, ...
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  http://schema.org/BusStop
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#Class
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#HotelRestaurant
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#Class
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#Landes
# ->pred  http://www.w3.org/2000/01/rdf-schema#subClassOf
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#NaturalHeritage
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#EntertainmentAndEvent
# ->pred  http://www.w3.org/2000/01/rdf-schema#subClassOf
# ->obj  http://schema.org/Event
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#shortDescription
# ->pred  http://www.w3.org/2000/01/rdf-schema#subPropertyOf
# ->obj  http://www.w3.org/2002/07/owl#topDataProperty
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#features
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#ObjectProperty
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#NaturalCuriosity
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Curiosité naturelle
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#NightClub
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Night club
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#Quantity
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#Class
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#RemarkableHouse
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Remarkable house
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#CityHeritage
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  City and village
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#HouseBoat
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#Class
#
#
# <class 'rdflib.term.BNode'>
# ->subj  n30116622feda4b918a38de49f3b91eb2b19
# ->pred  http://www.w3.org/2002/07/owl#unionOf
# ->obj  n30116622feda4b918a38de49f3b91eb2b20
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#HorseTour
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Itinéraire équestre
#
#
# <class 'rdflib.term.BNode'>
# ->subj  n30116622feda4b918a38de49f3b91eb2b85
# ->pred  http://www.w3.org/2002/07/owl#allValuesFrom
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#CateringAmenity
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#guided
# ->pred  http://www.w3.org/2000/01/rdf-schema#domain
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#Visit
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#DownhillSkiResort
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Downhill ski resort
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#Jetty
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Embarcadère
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#NauticalCentre
# ->pred  http://www.w3.org/2000/01/rdf-schema#subClassOf
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#SportsAndLeisurePlace
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#hasFeature
# ->pred  http://www.w3.org/2000/01/rdf-schema#domain
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#PointOfInterest
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#DepartementTourismCommittee
# ->pred  http://www.w3.org/2000/01/rdf-schema#subClassOf
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#TouristInformationCenter
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#RemembranceSite
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#Class
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#Concert
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Concert
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#lifeguarded
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#DatatypeProperty
#
#
# <class 'rdflib.term.BNode'>
# ->subj  n30116622feda4b918a38de49f3b91eb2b120
# ->pred  http://www.w3.org/2002/07/owl#allValuesFrom
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#ScaleReviewSystem
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#FoodEstablishment
# ->pred  http://www.w3.org/2000/01/rdf-schema#subClassOf
# ->obj  n30116622feda4b918a38de49f3b91eb2b95
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#Person
# ...
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Monastery or priory
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#requiredMinPersonCount
# ->pred  http://www.w3.org/2000/01/rdf-schema#comment
# ->obj  The minimum number of persons required for the Audience to be valid. Leave this property empty if no minimum is required.
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#GeneralPricingOffer
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#Class
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#IntroductionCourse
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Introduction course
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#Parade
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Défilé Cortège Parade
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#CulturalTheme
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Cultural
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#Dune
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Dune
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  http://purl.org/dc/elements/1.1/language
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#AnnotationProperty
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#charged
# ->pred  http://www.w3.org/2000/01/rdf-schema#domain
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#FeatureSpecification
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#Bungalow
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Bungalow, Mobil Home
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#FastFoodRestaurant
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#Class
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#saleOnSite
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#DatatypeProperty
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  http://schema.org/offers
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#ObjectProperty
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#SportsHall
# ->pred  http://www.w3.org/2000/01/rdf-schema#subClassOf
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#SportsAndLeisurePlace
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#Mine
# ->pred  http://www.w3.org/2000/01/rdf-schema#subClassOf
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#TechnicalHeritage
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#apeNaf
# ->pred  http://www.w3.org/2000/01/rdf-schema#comment
# ->obj  Code attribué par l'INSEE en référence à la nomenclature des activités françaises.
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#ScaleReview
# ->pred  http://www.w3.org/2000/01/rdf-schema#subClassOf
# ->obj  http://schema.org/Review
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#Rally
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Rallye
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#Bubble
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#Class
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#hasAudience
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#ObjectProperty
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#reducedMobilityAccess
# ->pred  https://www.datatourisme.gouv.fr/ontology/core#hasPriority
# ->obj  6.0
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#Calvary
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Calvary and parish enclosures
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#Church
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Church
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#LocalProductsShop
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Maison de pays, produits du terroir
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#Description
# ->pred  http://www.w3.org/2000/01/rdf-schema#comment
# ->obj  A description aggregates the textual description of a PointOfInterest and the Audience this description is dedicted to. For example, a PointOfInterest can have a description dedicated to Schools, and another one dedicated to general public. If a description has no Audience, then it is supposed to be dedicated to the general public.
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#providesFoodProduct
# ->pred  http://www.w3.org/2000/01/rdf-schema#comment
# ->obj  Le type de mêts qui est proposé
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#SportsAndLeisurePlace
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Site sportif, récréatif et de loisirs
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#DepartementTourismCommittee
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Département tourism committee
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#Forge
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Forge
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#TourGuideAgency
# ->pred  http://www.w3.org/2000/01/rdf-schema#subClassOf
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#TouristInformationCenter
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core
# ->pred  http://purl.org/dc/elements/1.1/language
# ->obj  EN
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#noSmoking
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#FunctionalProperty
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#BilliardRoom
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#Class
#
#
# <class 'rdflib.term.BNode'>
# ->subj  n30116622feda4b918a38de49f3b91eb2b82
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#first
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#CampingAndCaravanningFeatureSpecification
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#PicnicArea
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Aire de pique-nique
#
#
# <class 'rdflib.term.BNode'>
# ->subj  n30116622feda4b918a38de49f3b91eb2b40
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#first
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#TourPath
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#COVID19InOperationConfirmed
# ->pred  https://www.datatourisme.gouv.fr/ontology/core#hasPriority
# ->obj  9.2
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#hasBeenCreatedBy
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  a été créé par
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#features
# ->pred  http://www.w3.org/2000/01/rdf-schema#range
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#Amenity
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#NaturalHeritage
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Natural heritage
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  http://schema.org/AdministrativeArea
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#Class
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#AccommodationFeatureSpecification
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#Class
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  http://schema.org/AmusementPark
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#Class
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#Wetland
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#Class
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#Transporter
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Transporter
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#HolidayResort
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#Class
#
#
# <class 'rdflib.term.BNode'>
# ->subj  n30116622feda4b918a38de49f3b91eb2b106
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#Restriction
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#IslandPeninsula
# ->pred  http://www.w3.org/2000/01/rdf-schema#subClassOf
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#NaturalHeritage
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#OpeningHoursSpecification
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#Class
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#HotelSuite
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Suite
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#WorkMeeting
# ->pred  http://www.w3.org/2000/01/rdf-schema#subClassOf
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#BusinessEvent
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#Producer
# ->pred  http://www.w3.org/2000/01/rdf-schema#subClassOf
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#TastingProvider
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#meets
# ->pred  http://www.w3.org/2000/01/rdf-schema#domain
# ->obj  n30116622feda4b918a38de49f3b91eb2b19
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#hasDescription
# ->pred  http://www.w3.org/2000/01/rdf-schema#domain
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#PointOfInterest
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#Calvary
# ->pred  http://www.w3.org/2000/01/rdf-schema#subClassOf
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#ReligiousSite
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#hasEligibleAudience
# ->pred  http://www.w3.org/2000/01/rdf-schema#comment
# ->obj  Le type de public auquel ce prix s'applique. ex: Adolescents, Adultes, ...
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  http://schema.org/OpeningHoursSpecification
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#Class
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#Bog
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#Class
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#isConsumableFor
# ->pred  http://www.w3.org/2000/01/rdf-schema#comment
# ->obj  Permet de référencer un produit qui est un consommable d'un POI. Le consommable ne peut avoir d'existence propre (si le POI cible est supprimé, le consommable doit l'être également).
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#Fort
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Fort
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#Glacier
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#Class
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  http://schema.org/Event
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#Class
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#Offer
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#Class
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#isReferencedBy
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  est référencé par
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#Department
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Department
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#TouristBus
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Tourist bus
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#PlaceOfInterest
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Lieu
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#hasReviewValue
# ->pred  https://www.datatourisme.gouv.fr/ontology/core#hasPriority
# ->obj  5.5
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#endDate
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  End date
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#AccommodationProduct
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#Class
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#MiniGolf
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#Class
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#reviewExpirationDate
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Expiration date
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#requiredMaxPersonCount
# ->pred  http://www.w3.org/2000/01/rdf-schema#domain
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#PeopleAudience
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  http://schema.org/DanceEvent
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#Class
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#MTBRouteTheme
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#Class
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#ServiceProvider
# ->pred  http://www.w3.org/2000/01/rdf-schema#label
# ->obj  Prestataire de service
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#isRatingProvidedBy
# ->pred  http://www.w3.org/2000/01/rdf-schema#range
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#ReviewSystem
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#PeopleAudience
# ->pred  http://www.w3.org/2000/01/rdf-schema#subClassOf
# ->obj  https://www.datatourisme.gouv.fr/ontology/core#Audience
#
#
# <class 'rdflib.term.BNode'>
# ->subj  n30116622feda4b918a38de49f3b91eb2b36
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#rest
# ->obj  n30116622feda4b918a38de49f3b91eb2b37
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#insee
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#FunctionalProperty
#
#
# <class 'rdflib.term.URIRef'>
# ->subj  https://www.datatourisme.gouv.fr/ontology/core#Festival
# ->pred  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ->obj  http://www.w3.org/2002/07/owl#Class
